# %%
from DataFin import FMPClient, AWSClient

import os
import dotenv
import time
import time
import pandas as pd
from sqlalchemy import create_engine, text

dotenv.load_dotenv()

fmp_api_key = os.getenv('FMP_API_KEY')


s3_bucket = os.getenv('S3_BUCKET_NAME')
aws_access_key =  os.getenv('AWS_ACCESS_KEY_ID')
aws_secret_key =  os.getenv('AWS_SECRET_ACCESS_KEY')

rds_db_username = 'admin'
rds_db_connection_name = os.getenv('RDS_DB_CONNECTION_NAME')
rds_db_password = os.getenv('RDS_DB_PASSWORD')

fmp = FMPClient(fmp_api_key)

rds_engine = create_engine(f"mysql+mysqlconnector://{rds_db_username}:{rds_db_password}@{rds_db_connection_name}/test_db")
conn = rds_engine.connect()

aws = AWSClient(
    aws_access_key,
    aws_secret_key
)

s3 = aws.s3_client(
    'us-east-1'
)

# %%
combo_symbols = aws.get_json_from_s3(
    s3,
    s3_bucket,
    'ref-data',
    'combo-snp-nas'
)['data']

def micro_transform(raw_data):
    df = pd.DataFrame(raw_data)
    df['unique_id'] = df['symbol'] + '_' + df['date']
    df['premarket_change'] = df['open'] - df['close'].shift(-1)
    df['premarket_change_percent'] = ((df['open'] - df['close'].shift(-1)) / df['close'].shift(-1)) * 100
    return df 

def write_to_rds(df, table):
    df.to_sql(
        table,
        con=rds_engine,
        if_exists='append', 
        index=False
    )


for symbol in combo_symbols:

    data = aws.get_json_from_s3(
        s3,
        s3_bucket,
        'test-combo-eod-test',
        symbol
    )
    start = time.time()
    df = micro_transform(data)
    write_to_rds(df, 'eod-combo-test-1')
    end = time.time()
    total_time = end - start
    print(f'{symbol:<10} done, took {total_time:>6.2f} seconds')
# Out:
# ATVI       done, took   0.83 seconds
# ADBE       done, took   0.34 seconds
# ADP        done, took   0.29 seconds
# ABNB       done, took   0.32 seconds
# ALGN       done, took   0.28 seconds
# GOOGL      done, took   0.29 seconds
# GOOG       done, took   0.28 seconds
# AMZN       done, took   0.30 seconds
# AMD        done, took   0.28 seconds
# AEP        done, took   0.27 seconds
# AMGN       done, took   0.37 seconds
# ADI        done, took   0.34 seconds
# ANSS       done, took   0.34 seconds
# AAPL       done, took   0.32 seconds
# AMAT       done, took   0.34 seconds
# ASML       done, took   0.27 seconds
# AZN        done, took   0.27 seconds
# TEAM       done, took   0.28 seconds
# ADSK       done, took   0.26 seconds
# BKR        done, took   0.37 seconds
# BIIB       done, took   0.37 seconds
# BKNG       done, took   0.34 seconds
# AVGO       done, took   0.37 seconds
# CDNS       done, took   0.37 seconds
# CHTR       done, took   0.38 seconds
# CTAS       done, took   0.33 seconds
# CSCO       done, took   0.36 seconds
# CTSH       done, took   0.34 seconds
# CMCSA      done, took   0.36 seconds
# CEG        done, took   0.31 seconds
# CPRT       done, took   0.38 seconds
# CSGP       done, took   0.36 seconds
# COST       done, took   0.26 seconds
# CRWD       done, took   0.26 seconds
# CSX        done, took   0.45 seconds
# DDOG       done, took   0.27 seconds
# DXCM       done, took   0.37 seconds
# FANG       done, took   0.51 seconds
# DLTR       done, took   0.27 seconds
# EBAY       done, took   0.27 seconds
# EA         done, took   0.34 seconds
# ENPH       done, took   0.33 seconds
# EXC        done, took   0.34 seconds
# FAST       done, took   0.36 seconds
# FISV       done, took   0.31 seconds
# FTNT       done, took   0.37 seconds
# GILD       done, took   0.33 seconds
# GFS        done, took   0.33 seconds
# HON        done, took   0.35 seconds
# IDXX       done, took   0.38 seconds
# ILMN       done, took   0.34 seconds
# INTC       done, took   0.26 seconds
# INTU       done, took   0.25 seconds
# ISRG       done, took   0.26 seconds
# JD         done, took   0.25 seconds
# KDP        done, took   0.35 seconds
# KLAC       done, took   0.27 seconds
# KHC        done, took   0.33 seconds
# LRCX       done, took   0.33 seconds
# LCID       done, took   0.35 seconds
# LULU       done, took   0.35 seconds
# MAR        done, took   0.34 seconds
# MRVL       done, took   0.37 seconds
# MELI       done, took   0.34 seconds
# META       done, took   0.35 seconds
# MCHP       done, took   0.35 seconds
# MU         done, took   0.34 seconds
# MSFT       done, took   0.34 seconds
# MRNA       done, took   0.35 seconds
# MDLZ       done, took   0.34 seconds
# MNST       done, took   0.33 seconds
# NFLX       done, took   0.41 seconds
# NVDA       done, took   0.38 seconds
# NXPI       done, took   0.37 seconds
# ORLY       done, took   0.34 seconds
# ODFL       done, took   0.34 seconds
# PCAR       done, took   0.35 seconds
# PANW       done, took   0.36 seconds
# PAYX       done, took   0.36 seconds
# PYPL       done, took   0.45 seconds
# PDD        done, took   0.35 seconds
# PEP        done, took   0.42 seconds
# QCOM       done, took   0.45 seconds
# REGN       done, took   0.32 seconds
# RIVN       done, took   0.31 seconds
# ROST       done, took   0.35 seconds
# SGEN       done, took   0.32 seconds
# SIRI       done, took   0.32 seconds
# SBUX       done, took   0.34 seconds
# SNPS       done, took   0.33 seconds
# TMUS       done, took   0.32 seconds
# TSLA       done, took   0.33 seconds
# TXN        done, took   0.34 seconds
# VRSK       done, took   0.33 seconds
# VRTX       done, took   0.36 seconds
# WBA        done, took   0.36 seconds
# WBD        done, took   0.35 seconds
# WDAY       done, took   0.33 seconds
# XEL        done, took   0.37 seconds
# ZM         done, took   0.33 seconds
# ZS         done, took   0.33 seconds
# MMM        done, took   0.33 seconds
# AOS        done, took   0.34 seconds
# ABT        done, took   0.39 seconds
# ABBV       done, took   0.41 seconds
# ACN        done, took   0.37 seconds
# AES        done, took   0.32 seconds
# AFL        done, took   0.34 seconds
# A          done, took   0.37 seconds
# APD        done, took   0.40 seconds
# AKAM       done, took   0.41 seconds
# ALB        done, took   0.48 seconds
# ARE        done, took   0.33 seconds
# ALLE       done, took   0.34 seconds
# LNT        done, took   0.34 seconds
# ALL        done, took   0.32 seconds
# MO         done, took   0.33 seconds
# AMCR       done, took   0.36 seconds
# AEE        done, took   0.33 seconds
# AXP        done, took   0.32 seconds
# AIG        done, took   0.34 seconds
# AMT        done, took   0.36 seconds
# AWK        done, took   0.37 seconds
# AMP        done, took   0.33 seconds
# AME        done, took   0.33 seconds
# APH        done, took   0.36 seconds
# AON        done, took   0.34 seconds
# APA        done, took   0.33 seconds
# APO        done, took   0.37 seconds
# APTV       done, took   0.34 seconds
# ACGL       done, took   0.32 seconds
# ADM        done, took   0.34 seconds
# ANET       done, took   0.34 seconds
# AJG        done, took   0.33 seconds
# AIZ        done, took   0.32 seconds
# T          done, took   0.38 seconds
# ATO        done, took   0.38 seconds
# AZO        done, took   0.35 seconds
# AVB        done, took   0.32 seconds
# AVY        done, took   0.36 seconds
# AXON       done, took   0.34 seconds
# BALL       done, took   0.33 seconds
# BAC        done, took   0.33 seconds
# BAX        done, took   0.32 seconds
# BDX        done, took   0.34 seconds
# BRK-B      done, took   0.37 seconds
# BBY        done, took   0.32 seconds
# TECH       done, took   0.60 seconds
# BLK        done, took   0.35 seconds
# BX         done, took   0.34 seconds
# BK         done, took   0.35 seconds
# BA         done, took   0.35 seconds
# BSX        done, took   0.32 seconds
# BMY        done, took   0.35 seconds
# BR         done, took   0.35 seconds
# BRO        done, took   0.36 seconds
# BF-B       done, took   0.35 seconds
# BLDR       done, took   0.32 seconds
# BG         done, took   0.35 seconds
# BXP        done, took   0.34 seconds
# CHRW       done, took   0.51 seconds
# CZR        done, took   0.40 seconds
# CPT        done, took   0.40 seconds
# CPB        done, took   0.41 seconds
# COF        done, took   0.39 seconds
# CAH        done, took   0.40 seconds
# KMX        done, took   0.40 seconds
# CCL        done, took   0.33 seconds
# CARR       done, took   0.36 seconds
# CAT        done, took   0.35 seconds
# CBOE       done, took   0.35 seconds
# CBRE       done, took   0.33 seconds
# CDW        done, took   0.31 seconds
# COR        done, took   0.35 seconds
# CNC        done, took   0.32 seconds
# CNP        done, took   0.34 seconds
# CF         done, took   0.34 seconds
# CRL        done, took   0.34 seconds
# SCHW       done, took   0.35 seconds
# CVX        done, took   0.33 seconds
# CMG        done, took   0.34 seconds
# CB         done, took   0.34 seconds
# CHD        done, took   0.32 seconds
# CI         done, took   0.40 seconds
# CINF       done, took   0.36 seconds
# C          done, took   0.35 seconds
# CFG        done, took   0.35 seconds
# CLX        done, took   0.37 seconds
# CME        done, took   0.33 seconds
# CMS        done, took   0.33 seconds
# KO         done, took   0.35 seconds
# CL         done, took   0.33 seconds
# CAG        done, took   0.34 seconds
# COP        done, took   0.33 seconds
# ED         done, took   0.34 seconds
# STZ        done, took   0.31 seconds
# COO        done, took   0.34 seconds
# GLW        done, took   0.34 seconds
# CPAY       done, took   0.26 seconds
# CTVA       done, took   0.26 seconds
# CTRA       done, took   1.11 seconds
# CCI        done, took   0.97 seconds
# CMI        done, took   0.79 seconds
# CVS        done, took   0.59 seconds
# DHR        done, took   0.46 seconds
# DRI        done, took   0.48 seconds
# DVA        done, took   0.35 seconds
# DAY        done, took   0.40 seconds
# DECK       done, took   0.36 seconds
# DE         done, took   0.34 seconds
# DELL       done, took   0.35 seconds
# DAL        done, took   0.38 seconds
# DVN        done, took   0.29 seconds
# DLR        done, took   0.28 seconds
# DFS        done, took   0.43 seconds
# DG         done, took   0.42 seconds
# D          done, took   0.40 seconds
# DPZ        done, took   0.49 seconds
# DASH       done, took   0.35 seconds
# DOV        done, took   0.35 seconds
# DOW        done, took   0.36 seconds
# DHI        done, took   0.36 seconds
# DTE        done, took   0.40 seconds
# DUK        done, took   0.33 seconds
# DD         done, took   0.34 seconds
# EMN        done, took   0.35 seconds
# ETN        done, took   0.35 seconds
# ECL        done, took   0.32 seconds
# EIX        done, took   0.40 seconds
# EW         done, took   0.37 seconds
# ELV        done, took   0.58 seconds
# EMR        done, took   0.39 seconds
# ETR        done, took   0.41 seconds
# EOG        done, took   0.33 seconds
# EPAM       done, took   0.34 seconds
# EQT        done, took   0.34 seconds
# EFX        done, took   0.34 seconds
# EQIX       done, took   0.36 seconds
# EQR        done, took   0.54 seconds
# ERIE       done, took   0.35 seconds
# ESS        done, took   0.32 seconds
# EL         done, took   0.36 seconds
# EG         done, took   0.35 seconds
# EVRG       done, took   0.33 seconds
# ES         done, took   0.35 seconds
# EXE        done, took   0.32 seconds
# EXPE       done, took   0.35 seconds
# EXPD       done, took   0.32 seconds
# EXR        done, took   0.32 seconds
# XOM        done, took   0.33 seconds
# FFIV       done, took   0.34 seconds
# FDS        done, took   0.35 seconds
# FICO       done, took   0.35 seconds
# FRT        done, took   0.33 seconds
# FDX        done, took   0.32 seconds
# FIS        done, took   0.36 seconds
# FITB       done, took   0.32 seconds
# FSLR       done, took   0.35 seconds
# FE         done, took   0.35 seconds
# FI         done, took   0.32 seconds
# F          done, took   0.35 seconds
# FTV        done, took   0.35 seconds
# FOXA       done, took   0.32 seconds
# FOX        done, took   0.32 seconds
# BEN        done, took   0.32 seconds
# FCX        done, took   0.32 seconds
# GRMN       done, took   0.34 seconds
# IT         done, took   0.35 seconds
# GE         done, took   0.32 seconds
# GEHC       done, took   0.23 seconds
# GEV        done, took   0.29 seconds
# GEN        done, took   0.34 seconds
# GNRC       done, took   0.34 seconds
# GD         done, took   0.36 seconds
# GIS        done, took   0.32 seconds
# GM         done, took   0.31 seconds
# GPC        done, took   0.37 seconds
# GPN        done, took   0.34 seconds
# GL         done, took   0.33 seconds
# GDDY       done, took   0.33 seconds
# GS         done, took   0.34 seconds
# HAL        done, took   0.33 seconds
# HIG        done, took   0.34 seconds
# HAS        done, took   0.34 seconds
# HCA        done, took   0.40 seconds
# DOC        done, took   0.34 seconds
# HSIC       done, took   0.32 seconds
# HSY        done, took   0.39 seconds
# HES        done, took   0.35 seconds
# HPE        done, took   0.33 seconds
# HLT        done, took   0.33 seconds
# HOLX       done, took   0.33 seconds
# HD         done, took   0.33 seconds
# HRL        done, took   0.33 seconds
# HST        done, took   0.32 seconds
# HWM        done, took   0.36 seconds
# HPQ        done, took   0.36 seconds
# HUBB       done, took   0.34 seconds
# HUM        done, took   0.34 seconds
# HBAN       done, took   0.42 seconds
# HII        done, took   0.45 seconds
# IBM        done, took   0.42 seconds
# IEX        done, took   0.33 seconds
# ITW        done, took   0.33 seconds
# INCY       done, took   0.34 seconds
# IR         done, took   0.33 seconds
# PODD       done, took   0.33 seconds
# ICE        done, took   0.33 seconds
# IFF        done, took   0.33 seconds
# IP         done, took   0.34 seconds
# IPG        done, took   0.33 seconds
# IVZ        done, took   0.33 seconds
# INVH       done, took   0.33 seconds
# IQV        done, took   0.34 seconds
# IRM        done, took   0.33 seconds
# JBHT       done, took   0.34 seconds
# JBL        done, took   0.33 seconds
# JKHY       done, took   0.33 seconds
# J          done, took   0.34 seconds
# JNJ        done, took   0.34 seconds
# JCI        done, took   0.32 seconds
# JPM        done, took   0.34 seconds
# JNPR       done, took   0.33 seconds
# K          done, took   0.33 seconds
# KVUE       done, took   0.38 seconds
# KEY        done, took   0.39 seconds
# KEYS       done, took   0.37 seconds
# KMB        done, took   0.34 seconds
# KIM        done, took   0.32 seconds
# KMI        done, took   0.33 seconds
# KKR        done, took   0.38 seconds
# KR         done, took   0.36 seconds
# LHX        done, took   0.34 seconds
# LH         done, took   0.33 seconds
# LW         done, took   0.41 seconds
# LVS        done, took   0.34 seconds
# LDOS       done, took   0.34 seconds
# LEN        done, took   0.33 seconds
# LII        done, took   0.32 seconds
# LLY        done, took   0.33 seconds
# LIN        done, took   0.36 seconds
# LYV        done, took   0.33 seconds
# LKQ        done, took   0.33 seconds
# LMT        done, took   0.36 seconds
# L          done, took   0.35 seconds
# LOW        done, took   0.34 seconds
# LYB        done, took   0.34 seconds
# MTB        done, took   0.32 seconds
# MPC        done, took   0.32 seconds
# MKTX       done, took   0.32 seconds
# MMC        done, took   0.35 seconds
# MLM        done, took   0.32 seconds
# MAS        done, took   0.35 seconds
# MA         done, took   0.35 seconds
# MTCH       done, took   0.32 seconds
# MKC        done, took   0.35 seconds
# MCD        done, took   0.34 seconds
# MCK        done, took   0.32 seconds
# MDT        done, took   0.34 seconds
# MRK        done, took   0.32 seconds
# MET        done, took   0.32 seconds
# MTD        done, took   0.35 seconds
# MGM        done, took   0.31 seconds
# MAA        done, took   0.35 seconds
# MHK        done, took   0.34 seconds
# MOH        done, took   0.28 seconds
# TAP        done, took   0.35 seconds
# MPWR       done, took   0.33 seconds
# MCO        done, took   0.72 seconds
# MS         done, took   0.52 seconds
# MOS        done, took   0.33 seconds
# MSI        done, took   0.33 seconds
# MSCI       done, took   0.33 seconds
# NDAQ       done, took   0.34 seconds
# NTAP       done, took   0.33 seconds
# NEM        done, took   0.39 seconds
# NWSA       done, took   0.31 seconds
# NWS        done, took   0.35 seconds
# NEE        done, took   0.34 seconds
# NKE        done, took   0.33 seconds
# NI         done, took   0.33 seconds
# NDSN       done, took   0.33 seconds
# NSC        done, took   0.52 seconds
# NTRS       done, took   0.35 seconds
# NOC        done, took   0.32 seconds
# NCLH       done, took   0.32 seconds
# NRG        done, took   0.33 seconds
# NUE        done, took   0.37 seconds
# NVR        done, took   0.33 seconds
# OXY        done, took   0.34 seconds
# OMC        done, took   0.35 seconds
# ON         done, took   0.34 seconds
# OKE        done, took   0.32 seconds
# ORCL       done, took   0.34 seconds
# OTIS       done, took   0.35 seconds
# PKG        done, took   0.34 seconds
# PLTR       done, took   0.34 seconds
# PARA       done, took   0.35 seconds
# PH         done, took   0.35 seconds
# PAYC       done, took   0.33 seconds
# PNR        done, took   0.32 seconds
# PFE        done, took   0.32 seconds
# PCG        done, took   0.33 seconds
# PM         done, took   0.35 seconds
# PSX        done, took   0.32 seconds
# PNW        done, took   0.35 seconds
# PNC        done, took   0.33 seconds
# POOL       done, took   0.32 seconds
# PPG        done, took   0.33 seconds
# PPL        done, took   0.32 seconds
# PFG        done, took   0.32 seconds
# PG         done, took   0.33 seconds
# PGR        done, took   0.33 seconds
# PLD        done, took   0.33 seconds
# PRU        done, took   0.33 seconds
# PEG        done, took   0.34 seconds
# PTC        done, took   0.34 seconds
# PSA        done, took   0.34 seconds
# PHM        done, took   0.35 seconds
# PWR        done, took   0.32 seconds
# DGX        done, took   0.36 seconds
# RL         done, took   0.34 seconds
# RJF        done, took   0.34 seconds
# RTX        done, took   0.35 seconds
# O          done, took   0.33 seconds
# REG        done, took   0.33 seconds
# RF         done, took   0.40 seconds
# RSG        done, took   0.37 seconds
# RMD        done, took   0.42 seconds
# RVTY       done, took   0.34 seconds
# ROK        done, took   0.32 seconds
# ROL        done, took   0.35 seconds
# ROP        done, took   0.32 seconds
# RCL        done, took   0.31 seconds
# SPGI       done, took   0.32 seconds
# CRM        done, took   0.34 seconds
# SBAC       done, took   0.32 seconds
# SLB        done, took   0.32 seconds
# STX        done, took   0.32 seconds
# SRE        done, took   0.34 seconds
# NOW        done, took   0.36 seconds
# SHW        done, took   0.34 seconds
# SPG        done, took   0.34 seconds
# SWKS       done, took   0.58 seconds
# SJM        done, took   0.32 seconds
# SW         done, took   0.32 seconds
# SNA        done, took   0.33 seconds
# SOLV       done, took   0.29 seconds
# SO         done, took   0.33 seconds
# LUV        done, took   0.33 seconds
# SWK        done, took   0.32 seconds
# STT        done, took   0.32 seconds
# STLD       done, took   0.33 seconds
# STE        done, took   0.33 seconds
# SYK        done, took   0.59 seconds
# SMCI       done, took   0.34 seconds
# SYF        done, took   0.31 seconds
# SYY        done, took   0.32 seconds
# TROW       done, took   0.35 seconds
# TTWO       done, took   0.34 seconds
# TPR        done, took   0.35 seconds
# TRGP       done, took   0.34 seconds
# TGT        done, took   0.32 seconds
# TEL        done, took   0.35 seconds
# TDY        done, took   0.33 seconds
# TER        done, took   0.34 seconds
# TPL        done, took   0.35 seconds
# TXT        done, took   0.32 seconds
# TMO        done, took   0.32 seconds
# TJX        done, took   0.32 seconds
# TKO        done, took   0.33 seconds
# TSCO       done, took   0.35 seconds
# TT         done, took   0.33 seconds
# TDG        done, took   0.32 seconds
# TRV        done, took   0.32 seconds
# TRMB       done, took   0.32 seconds
# TFC        done, took   0.32 seconds
# TYL        done, took   0.32 seconds
# TSN        done, took   0.32 seconds
# USB        done, took   0.32 seconds
# UBER       done, took   0.59 seconds
# UDR        done, took   0.83 seconds
# ULTA       done, took   0.46 seconds
# UNP        done, took   0.44 seconds
# UAL        done, took   0.34 seconds
# UPS        done, took   0.33 seconds
# URI        done, took   0.32 seconds
# UNH        done, took   0.33 seconds
# UHS        done, took   0.34 seconds
# VLO        done, took   0.33 seconds
# VTR        done, took   0.33 seconds
# VLTO       done, took   0.40 seconds
# VRSN       done, took   0.38 seconds
# VZ         done, took   0.38 seconds
# VTRS       done, took   0.40 seconds
# VICI       done, took   0.40 seconds
# V          done, took   0.32 seconds
# VST        done, took   0.34 seconds
# VMC        done, took   0.33 seconds
# WRB        done, took   0.43 seconds
# GWW        done, took   0.42 seconds
# WAB        done, took   0.42 seconds
# WMT        done, took   0.39 seconds
# DIS        done, took   0.58 seconds
# WM         done, took   0.33 seconds
# WAT        done, took   0.35 seconds
# WEC        done, took   0.32 seconds
# WFC        done, took   0.32 seconds
# WELL       done, took   0.32 seconds
# WST        done, took   0.32 seconds
# WDC        done, took   0.32 seconds
# WY         done, took   0.35 seconds
# WSM        done, took   0.32 seconds
# WMB        done, took   0.30 seconds
# WTW        done, took   0.35 seconds
# WYNN       done, took   0.32 seconds
# XYL        done, took   0.32 seconds
# YUM        done, took   0.32 seconds
# ZBRA       done, took   0.36 seconds
# ZBH        done, took   0.58 seconds
# ZTS        done, took   0.44 seconds

# %%
pd.read_sql('''
SELECT 
    table_schema AS database_name,
    ROUND(SUM(data_length + index_length) / 1024 / 1024, 2) AS size_mb
FROM 
    information_schema.tables
WHERE 
    table_schema = 'test_db'
GROUP BY 
    table_schema;

''', conn)
# Out:
#   database_name  size_mb
# 0       test_db    87.86
