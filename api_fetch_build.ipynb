# %% [markdown]
# #### load packages

# %%
from dotenv import load_dotenv
import os
import requests
from sqlalchemy import create_engine, text
import pandas as pd

from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# %% [markdown]
# #### load hidden environment variables

# %%
load_dotenv()

fmp_api_key = os.getenv('fmp_api_key')

db_name = os.getenv('db_name')
db_password = os.getenv('db_password')

# %% [markdown]
# #### connect to mysql db
#
# this is the db taht we spun up in a docker container and check to see that it is empty if its teh first time that we set it up

# %%
mysql_engine = create_engine(f"mysql+mysqlconnector://root:{db_password}@127.0.0.1:3306/{db_name}")
conn = mysql_engine.connect()
list(conn.execute(text("show tables;")))

# %%
pd.read_sql('show tables', conn)

# %%
import datetime
from dateutil.relativedelta import relativedelta

# Get today's date
today = datetime.datetime.now()

time_delta_5_year = today - relativedelta(years=5) + datetime.timedelta(days=1)

# %%
symbol = 'sofi'
_symbol = symbol.upper()
_from = time_delta_5_year.strftime('%Y-%m-%d')
_to = today.strftime('%Y-%m-%d')

url = f'https://financialmodelingprep.com/stable/historical-price-eod/full?symbol={_symbol}&from={_from}&to={_to}&apikey={fmp_api_key}'

r = requests.get(url, timeout=10)

# %%
r.status_code
# Out:
# 401

# %%
# Test with a reliable public API
test_url = "https://httpbin.org/get"
test_r = requests.get(test_url, timeout=5)
print(f"Test status code: {test_r.status_code}")
print(test_r.json())

# %%
import requests, time
start = time.time()
r = requests.get(f"https://financialmodelingprep.com/stable/historical-price-eod/full?symbol=AAPL&apikey={fmp_api_key}", timeout=5)
print(r.status_code)
print("Elapsed:", time.time() - start)
r.json()
# Out:
# 200
# Elapsed: 0.30344700813293457
# [{'symbol': 'AAPL',
#   'date': '2025-04-04',
#   'open': 193.89,
#   'high': 199.88,
#   'low': 187.34,
#   'close': 188.38,
#   'volume': 124921508,
#   'change': -5.51,
#   'changePercent': -2.84,
#   'vwap': 192.3725},
#  {'symbol': 'AAPL',
#   'date': '2025-04-03',
#   'open': 205.54,
#   'high': 207.49,
#   'low': 201.25,
#   'close': 203.19,
#   'volume': 103419006,
#   'change': -2.35,
#   'changePercent': -1.14,
#   'vwap': 204.3675},
#  {'symbol': 'AAPL',
#   'date': '2025-04-02',
#   'open': 221.32,
#   'high': 225.19,
#   'low': 221.02,
#   'close': 223.89,
#   'volume': 35905904,
#   'change': 2.57,
#   'changePercent': 1.16,
#   'vwap': 222.855},
#  {'symbol': 'AAPL',
#   'date': '2025-04-01',
#   'open': 219.81,
#   'high': 223.68,
#   'low': 218.9,
#   'close': 223.19,
#   'volume': 36412740,
#   'change': 3.38,
#   'changePercent': 1.54,
#   'vwap': 221.395},
#  {'symbol': 'AAPL',
#   'date': '2025-03-31',
#   'open': 217.01,
# ...
