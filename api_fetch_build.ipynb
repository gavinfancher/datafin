# %%
from dotenv import load_dotenv
import os
import csv
import time
import requests
from sqlalchemy import create_engine, text
import pandas as pd

from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# %%
load_dotenv()

fmp_api_key = os.getenv('FMP_API_KEY')

db_name = os.getenv('DB_NAME')
db_password = os.getenv('DB_PASSWORD')

snp_path = os.path.join('data-ref', 'snp500.csv')
nas_path = os.path.join('data-ref', 'nasdaq.csv')

# %%
mysql_engine = create_engine(f"mysql+mysqlconnector://root:{db_password}@127.0.0.1:3306/{db_name}")
conn = mysql_engine.connect()
list(conn.execute(text("show tables;")))
# Out:
# []

# %%
from datetime import datetime

def format_date_time_object(
    datetime_object: datetime,
    with_time: bool = False
) -> str:
    """
    DEPS:
        datetime -- in requirements.txt
    DEF:
        format a datetime object as a string.
    
    ARGS:
        datetime_object: the datetime object to format
        with_time: whether to include the time in the formatted string
    
    RETURNS:
        a formatted date string
    """

    if with_time:
        return datetime_object.strftime("%Y-%m-%d %H:%M:%S")
    else:
        return datetime_object.strftime("%Y-%m-%d")

# %%
def api_call_get(
    url: str, 
    params: dict,
    headers: dict = None,
    return_other_than_json: bool = False
) -> object:
    """
    DEPS:
        requests
    DEF:
        takes a url and parameters and packages and sends the get requests and returns json or response object
    ARGS:
        url: the url endpoint you want to call
        params: {key: value} pairs that serve as parameters for api
        headers: pass headers as {key: value} pairs for more advance config and authorization
        return_other_than_json: returns the response object rather than the json formatted response which allows for more inspection
    RETURNS:
        list of dicts or reponse object if successful, statuscode if not
    """
    if headers is not None:
        response = requests.get(url, params=params, headers=headers)
        if response.status_code != 200:
            return response.raise_for_status()
        else:
            return response.json()
    else:
        response = requests.get(url, params=params)
        if response.status_code != 200:
            return response.raise_for_status()
        else:
            if response.json() == []:
                return "empty response"
            else:
                return response.json()

# %%
def call_eod(symbol):
    today = datetime.now()
    time_delta_5_year = today - relativedelta(years=5) + timedelta(days=1) ## max amount of data i can get form api


    base_url = "https://financialmodelingprep.com/stable/historical-price-eod/full"

    today_param = format_date_time_object(today)
    time_delta_param = format_date_time_object(time_delta_5_year)


    params = {
        "symbol": symbol,
        "apikey": fmp_api_key,
        "from": time_delta_param,
        "to": today_param
    }

    response = api_call_get(base_url, params=params)

    return response

def call_eod_5_min(symbol):
    today = datetime.now()

    base_url = "https://financialmodelingprep.com/stable/historical-chart/5min"

    today_param = format_date_time_object(today)


    params = {
        "symbol": symbol,
        "apikey": fmp_api_key,
        "from": today_param,
        "to": today_param
    }

    response = api_call_get(base_url, params=params)

    return response

# %%
symbol = 'pltr'.upper()
response = call_eod_5_min(symbol)

# %%
df = pd.DataFrame(response)
df['symbol'] = f'{symbol}'
df['date_time_id'] = df['symbol'] + '_' + df['date']
df
# Out:
#                    date     open      low     high   close   volume symbol  \
# 0   2025-04-10 15:55:00  88.7900  87.8769  88.7900  88.540  2588027   PLTR
# 1   2025-04-10 15:50:00  87.8277  87.8277  88.7300  88.715  2000806   PLTR
# 2   2025-04-10 15:45:00  86.9250  86.7600  87.3200  87.315  1444357   PLTR
# 3   2025-04-10 15:40:00  87.7250  86.8781  87.7300  86.880  1528924   PLTR
# 4   2025-04-10 15:35:00  87.8550  87.6500  88.2099  87.710  1109924   PLTR
# ..                  ...      ...      ...      ...     ...      ...    ...
# 73  2025-04-10 09:50:00  89.9400  89.3100  90.3500  89.470  2159591   PLTR
# 74  2025-04-10 09:45:00  88.6950  88.6950  90.1800  89.925  2372610   PLTR
# 75  2025-04-10 09:40:00  89.5795  88.3501  89.5795  88.830  2679434   PLTR
# 76  2025-04-10 09:35:00  89.4600  89.1200  90.1300  89.525  3073888   PLTR
# 77  2025-04-10 09:30:00  88.4000  88.3500  89.6800  89.160  4153385   PLTR
#
#                 date_time_id
# 0   PLTR_2025-04-10 15:55:00
# 1   PLTR_2025-04-10 15:50:00
# 2   PLTR_2025-04-10 15:45:00
# 3   PLTR_2025-04-10 15:40:00
# 4   PLTR_2025-04-10 15:35:00
# ..                       ...
# 73  PLTR_2025-04-10 09:50:00
# 74  PLTR_2025-04-10 09:45:00
# 75  PLTR_2025-04-10 09:40:00
# 76  PLTR_2025-04-10 09:35:00
# 77  PLTR_2025-04-10 09:30:00
#
# [78 rows x 8 columns]

# %%
def transform_and_commit_data(
    response: object
) -> None:
    """
    DEPS:
        pandas, established connection to a sql database, in this case a mysql data base
    DEF:
        transform response json to df, make a primary key transformation and then write to a sql table
    ARGS:
        reponse: response object from an api in json format
    RETURNS:
        nothing, commits to the db or throws an error, the data should be appended if already exists
    """
    df = pd.DataFrame(response)
    df['date_time_id'] = df['symbol'] + '_' + df['date']
    cols = ['date_time_id'] + [col for col in df.columns if col != 'date_time_id']
    df = df[cols]a
    df.to_sql(
        name='raw_ingestion_test_5_min',
        con=mysql_engine,
        if_exists='append',
        index=False,
        chunksize=1000
    )
    conn.commit()

# %%
def transform_and_commit_data_2(
    response: object
) -> None:
    """
    DEPS:
        pandas, established connection to a sql database, in this case a mysql data base
    DEF:
        transform response json to df, make a primary key transformation and then write to a sql table
    ARGS:
        reponse: response object from an api in json format
    RETURNS:
        nothing, commits to the db or throws an error, the data should be appended if already exists
    """
    df = pd.DataFrame(response)
    df['symbol'] = f'{symbol}'
    df['date_time_id'] = df['symbol'] + '_' + df['date']
    df.to_sql(
        name='raw_ingestion_test_5_min',
        con=rds_engine,
        if_exists='append',
        index=False,
        chunksize=1000
    )
    conn.commit()

# %%
import mysql.connector
import os
from dotenv import load_dotenv
import time

load_dotenv()

rds_db_connection = os.getenv('RDS_DB_CONNECTION_NAME')
rds_db_password = os.getenv('RDS_DB_PASSWORD')

rds_engine = create_engine(f"mysql+mysqlconnector://admin:{rds_db_password}@{rds_db_connection}:3306/test_db")
conn = rds_engine.connect()
# conn = mysql.connector.connect(
#     host=rds_db_connection,
#     user="admin",
#     password=rds_db_password,
#     port=3306,
#     connection_timeout=10
# )

# %%
pd.read_sql("""
select * from raw_ingestion_test_5_min
""", conn)
# Out:
#                    date     open      low     high   close   volume symbol  \
# 0   2025-04-10 15:55:00  88.7900  87.8769  88.7900  88.540  2588027   PLTR
# 1   2025-04-10 15:50:00  87.8277  87.8277  88.7300  88.715  2000806   PLTR
# 2   2025-04-10 15:45:00  86.9250  86.7600  87.3200  87.315  1444357   PLTR
# 3   2025-04-10 15:40:00  87.7250  86.8781  87.7300  86.880  1528924   PLTR
# 4   2025-04-10 15:35:00  87.8550  87.6500  88.2099  87.710  1109924   PLTR
# ..                  ...      ...      ...      ...     ...      ...    ...
# 73  2025-04-10 09:50:00  89.9400  89.3100  90.3500  89.470  2159591   PLTR
# 74  2025-04-10 09:45:00  88.6950  88.6950  90.1800  89.925  2372610   PLTR
# 75  2025-04-10 09:40:00  89.5795  88.3501  89.5795  88.830  2679434   PLTR
# 76  2025-04-10 09:35:00  89.4600  89.1200  90.1300  89.525  3073888   PLTR
# 77  2025-04-10 09:30:00  88.4000  88.3500  89.6800  89.160  4153385   PLTR
#
#                 date_time_id
# 0   PLTR_2025-04-10 15:55:00
# 1   PLTR_2025-04-10 15:50:00
# 2   PLTR_2025-04-10 15:45:00
# 3   PLTR_2025-04-10 15:40:00
# 4   PLTR_2025-04-10 15:35:00
# ..                       ...
# 73  PLTR_2025-04-10 09:50:00
# 74  PLTR_2025-04-10 09:45:00
# 75  PLTR_2025-04-10 09:40:00
# 76  PLTR_2025-04-10 09:35:00
# 77  PLTR_2025-04-10 09:30:00
#
# [78 rows x 8 columns]

# %%
def transform_and_commit_data_2(
    response: object
) -> None:
    """
    DEPS:
        pandas, established connection to a sql database, in this case a mysql data base
    DEF:
        transform response json to df, make a primary key transformation and then write to a sql table
    ARGS:
        reponse: response object from an api in json format
    RETURNS:
        nothing, commits to the db or throws an error, the data should be appended if already exists
    """
    df = pd.DataFrame(response)
    df['symbol'] = f'{symbol}'
    df['date_time_id'] = df['symbol'] + '_' + df['date']
    df.to_sql(
        name='raw_ingestion_test_5_min',
        con=rds_engine,
        if_exists='append',
        index=False,
        chunksize=1000
    )
    conn.commit()

symbol = 'pltr'.upper()
response = call_eod_5_min(symbol)
transform_and_commit_data_2(response)

# %%
nas = []
with open(nas_path, 'r', newline='') as f:
    csv_reader = csv.reader(f)
    
    for row in csv_reader:
        nas.append(row[0])

snp = []
with open(snp_path, 'r', newline='') as f:
    csv_reader = csv.reader(f)
    
    for row in csv_reader:
        snp.append(row[0])

not_in = []
for q in nas:
    if q not in snp:
        not_in.append(q)
    else:
        continue

# %%
count = 1
start_ = time.time()
for s in snp:
    start_time = time.time()

    raw_json_reponse = call_eod(s)
    df = transform_and_commit_data(raw_json_reponse)
    
    elapsed_time = time.time() - start_time
    if len(s) == 1:
        print(f'commited {s}     to table -- time: {elapsed_time:.2f} -- count {count}')
    elif len(s) == 2:
        print(f'commited {s}    to table -- time: {elapsed_time:.2f} -- count {count}')
    elif len(s) == 3:
        print(f'commited {s}   to table -- time: {elapsed_time:.2f} -- count {count}')
    elif len(s) == 4:
        print(f'commited {s}  to table -- time: {elapsed_time:.2f} -- count {count}')
    else:
        print(f'commited {s} to table -- time: {elapsed_time:.2f} -- count {count}')
    count += 1

whole_loop = time.time() - start_ 
print(f'whole loop has taken {round(whole_loop, 2)}')

start_ = time.time()
for s in not_in:
    start_time = time.time()

    raw_json_reponse = call_eod(s)
    df = transform_and_commit_data(raw_json_reponse)
    
    elapsed_time = time.time() - start_time
    if len(s) == 3:
        print(f'commited {s}   to table -- time: {elapsed_time:.2f} -- count {count}')
    if len(s) == 4:
        print(f'commited {s}  to table -- time: {elapsed_time:.2f} -- count {count}')
    else:
        print(f'commited {s} to table -- time: {elapsed_time:.2f} -- count {count}')
    count += 1

whole_loop = time.time() - start_ 
print(f'whole loop has taken {round(whole_loop, 2)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 23
#      21 count = 1
#      22 start_ = time.time()
# ---> 23 for s in snp:
#      24     start_time = time.time()
#      26     raw_json_reponse = call_eod(s)
#
# NameError: name 'snp' is not defined

# %%
pd.read_sql(f""" 

SELECT COUNT(date_time_id)
FROM raw_ingestion_test

""", conn)
# Out:
#    COUNT(date_time_id)
# 0              1293836

# %%
pd.read_sql(f""" 
SELECT 
    table_name AS `Table`,
    round(((data_length + index_length) / 1024 / 1024), 2) `Size (MB)`
FROM information_schema.TABLES
WHERE table_schema = "{db_name}"
AND table_name = "raw_ingestion_test";
            """, conn)
# Out:
#                 Table  Size (MB)
# 0  raw_ingestion_test      154.7

# %%
pd.read_sql(f""" 
select * 
from raw_ingestion_test
where 
    changePercent >= 20.0 
    and symbol = "PLTR"
                    """, conn)
# Out:
#       date_time_id symbol        date   open   high    low  close     volume  \
# 0  PLTR_2022-02-24   PLTR  2022-02-24   9.75  11.87   9.74  11.83  118793047
# 1  PLTR_2021-01-22   PLTR  2021-01-22  25.85  32.65  25.82  32.58  157240221
# 2  PLTR_2020-11-25   PLTR  2020-11-25  23.96  29.75  23.69  29.05  203256795
# 3  PLTR_2022-02-24   PLTR  2022-02-24   9.75  11.87   9.74  11.83  118793047
# 4  PLTR_2021-01-22   PLTR  2021-01-22  25.85  32.65  25.82  32.58  157240221
# 5  PLTR_2020-11-25   PLTR  2020-11-25  23.96  29.75  23.69  29.05  203256795
#
#    change  changePercent   vwap
# 0    2.08          21.33  11.04
# 1    6.73          26.03  29.79
# 2    5.09          21.24  27.19
# 3    2.08          21.33  11.04
# 4    6.73          26.03  29.79
# 5    5.09          21.24  27.19

# %%
import boto3
import json

aws_access_key_id = os.getenv('AWS_ACCESS_KEY_ID')
aws_secret_access_key = os.getenv('AWS_SECRET_ACCESS_KEY')
region_name = 'us-east-1' 

s3 = boto3.client(
    's3',
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=region_name
)

# %%
symbol = 'pltr'.upper()
response = call_eod(symbol)

# %%
def upload_to_s3(data):
    bucket_name = os.getenv('S3_BUCKET_NAME')
    file_name = 'pltr-5-eod-data.json'
    s3.put_object(
        Bucket=bucket_name,
        Key=file_name,
        Body=json.dumps(data),
        ContentType='application/json'
    )
    print('Data uploaded successfully to S3')

# %%
response
# Out:
# [{'symbol': 'PLTR',
#   'date': '2025-04-10',
#   'open': 88.4,
#   'high': 90.78,
#   'low': 84.14,
#   'close': 88.59,
#   'volume': 123826122,
#   'change': 0.19,
#   'changePercent': 0.21493,
#   'vwap': 87.98},
#  {'symbol': 'PLTR',
#   'date': '2025-04-09',
#   'open': 78.19,
#   'high': 93.33,
#   'low': 77.27,
#   'close': 92.01,
#   'volume': 187244300,
#   'change': 13.82,
#   'changePercent': 17.67,
#   'vwap': 85.2},
#  {'symbol': 'PLTR',
#   'date': '2025-04-08',
#   'open': 83.29,
#   'high': 86.11,
#   'low': 75.22,
#   'close': 77.32,
#   'volume': 135345600,
#   'change': -5.97,
#   'changePercent': -7.17,
#   'vwap': 80.49},
#  {'symbol': 'PLTR',
#   'date': '2025-04-07',
#   'open': 66.65,
#   'high': 81.8,
#   'low': 66.12,
#   'close': 77.84,
#   'volume': 169083700,
#   'change': 11.19,
#   'changePercent': 16.79,
#   'vwap': 73.1},
#  {'symbol': 'PLTR',
#   'date': '2025-04-04',
#   'open': 80.07,
#   'high': 80.98,
#   'low': 71.93,
#   'close': 74.01,
#   'volume': 147323200,
#   'change': -6.06,
#   'changePercent': -7.57,
#   'vwap': 76.75},
#  {'symbol': 'PLTR',
#   'date': '2025-04-03',
#   'open': 81.25,
#   'high': 85.68,
#   'low': 81.01,
#   'close': 83.6,
#   'volume': 93878200,
#   'change': 2.35,
#   'changePercent': 2.89,
#   'vwap': 82.89},
#  {'symbol': 'PLTR',
#   'date': '2025-04-02',
#   'open': 82.4,
#   'high': 88.4,
#   'low': 82.3,
#   'close': 87.45,
#   'volume': 96563100,
#   'change': 5.05,
#   'changePercent': 6.13,
#   'vwap': 85.14},
#  {'symbol': 'PLTR',
#   'date': '2025-04-01',
#   'open': 83.89,
#   'high': 85.28,
#   'low': 81.82,
#   'close': 84.68,
#   'volume': 78980700,
#   'change': 0.79,
#   'changePercent': 0.94171,
#   'vwap': 83.92},
#  {'symbol': 'PLTR',
#   'date': '2025-03-31',
#   'open': 80,
#   'high': 84.65,
#   'low': 78.75,
#   'close': 84.4,
#   'volume': 108092900,
#   'change': 4.4,
#   'changePercent': 5.5,
#   'vwap': 81.95},
#  {'symbol': 'PLTR',
#   'date': '2025-03-28',
#   'open': 89.34,
#   'high': 89.38,
#   'low': 84.1,
#   'close': 85.85,
#   'volume': 91091700,
#   'change': -3.49,
#   'changePercent': -3.91,
#   'vwap': 87.17},
#  {'symbol': 'PLTR',
#   'date': '2025-03-27',
#   'open': 91.01,
#   'high': 93.65,
#   'low': 89.67,
#   'close': 90.09,
#   'volume': 82823000,
#   'change': -0.92,
#   'changePercent': -1.01,
#   'vwap': 91.11},
#  {'symbol': 'PLTR',
#   'date': '2025-03-26',
#   'open': 96.29,
#   'high': 97.3,
#   'low': 90.82,
#   'close': 92.28,
#   'volume': 82138300,
#   'change': -4.01,
#   'changePercent': -4.16,
#   'vwap': 94.17},
#  {'symbol': 'PLTR',
#   'date': '2025-03-25',
#   'open': 97.22,
#   'high': 98.17,
#   'low': 95.08,
#   'close': 96.5,
#   'volume': 78015300,
#   'change': -0.72,
#   'changePercent': -0.74059,
#   'vwap': 96.74},
#  {'symbol': 'PLTR',
#   'date': '2025-03-24',
#   'open': 93.4,
#   'high': 97.39,
#   'low': 92.28,
#   'close': 96.75,
#   'volume': 112164700,
#   'change': 3.35,
#   'changePercent': 3.59,
#   'vwap': 94.95},
#  {'symbol': 'PLTR',
#   'date': '2025-03-21',
#   'open': 85.85,
#   'high': 91.07,
#   'low': 84.46,
#   'close': 90.96,
#   'volume': 116748700,
#   'change': 5.11,
#   'changePercent': 5.95,
#   'vwap': 88.08},
#  {'symbol': 'PLTR',
#   'date': '2025-03-20',
#   'open': 85.54,
#   'high': 89.8,
#   'low': 85.12,
#   'close': 87.39,
#   'volume': 105547400,
#   'change': 1.85,
#   'changePercent': 2.16,
#   'vwap': 86.96},
#  {'symbol': 'PLTR',
#   'date': '2025-03-19',
#   'open': 84.55,
#   'high': 87.99,
#   'low': 82.86,
#   'close': 86.1,
#   'volume': 89797400,
#   'change': 1.55,
#   'changePercent': 1.83,
#   'vwap': 85.38},
#  {'symbol': 'PLTR',
#   'date': '2025-03-18',
#   'open': 85.78,
#   'high': 86.17,
#   'low': 81.8,
#   'close': 83.89,
#   'volume': 93236500,
#   'change': -1.89,
#   'changePercent': -2.2,
#   'vwap': 84.41},
#  {'symbol': 'PLTR',
#   'date': '2025-03-17',
#   'open': 88.44,
#   'high': 88.82,
#   'low': 84.5,
#   'close': 87.35,
#   'volume': 99348900,
#   'change': -1.09,
#   'changePercent': -1.23,
#   'vwap': 87.28},
#  {'symbol': 'PLTR',
#   'date': '2025-03-14',
#   'open': 82.97,
#   'high': 87.27,
#   'low': 82.16,
#   'close': 86.24,
#   'volume': 113985000,
#   'change': 3.27,
#   'changePercent': 3.94,
#   'vwap': 84.66},
#  {'symbol': 'PLTR',
#   'date': '2025-03-13',
#   'open': 82.85,
#   'high': 83.74,
#   'low': 78.32,
#   'close': 79.62,
#   'volume': 100927200,
#   'change': -3.23,
#   'changePercent': -3.9,
#   'vwap': 81.13},
#  {'symbol': 'PLTR',
#   'date': '2025-03-12',
#   'open': 83.48,
#   'high': 84.55,
#   'low': 79.86,
#   'close': 83.65,
#   'volume': 116525100,
#   'change': 0.17,
#   'changePercent': 0.20364,
#   'vwap': 82.89},
#  {'symbol': 'PLTR',
#   'date': '2025-03-11',
#   'open': 75.79,
#   'high': 80.75,
#   'low': 75.53,
#   'close': 78.05,
#   'volume': 109351500,
#   'change': 2.26,
#   'changePercent': 2.98,
#   'vwap': 77.53},
#  {'symbol': 'PLTR',
#   'date': '2025-03-10',
#   'open': 82,
#   'high': 82.69,
#   'low': 74.57,
#   'close': 76.38,
#   'volume': 136843800,
#   'change': -5.62,
#   'changePercent': -6.85,
#   'vwap': 78.91},
#  {'symbol': 'PLTR',
#   'date': '2025-03-07',
#   'open': 80.03,
#   'high': 85.16,
#   'low': 79.15,
#   'close': 84.91,
#   'volume': 105377100,
#   'change': 4.88,
#   'changePercent': 6.1,
#   'vwap': 82.31},
#  {'symbol': 'PLTR',
#   'date': '2025-03-06',
#   'open': 87.5,
#   'high': 88.34,
#   'low': 80.01,
#   'close': 80.46,
#   'volume': 117340600,
#   'change': -7.04,
#   'changePercent': -8.05,
#   'vwap': 84.08},
#  {'symbol': 'PLTR',
#   'date': '2025-03-05',
#   'open': 86.35,
#   'high': 90.3,
#   'low': 82.5,
#   'close': 90.13,
#   'volume': 116053000,
#   'change': 3.78,
#   'changePercent': 4.38,
#   'vwap': 87.32},
#  {'symbol': 'PLTR',
#   'date': '2025-03-04',
#   'open': 80.16,
#   'high': 88.5,
#   'low': 79.3,
#   'close': 84.4,
#   'volume': 116800300,
#   'change': 4.24,
#   'changePercent': 5.29,
#   'vwap': 83.09},
#  {'symbol': 'PLTR',
#   'date': '2025-03-03',
#   'open': 88.55,
#   'high': 90.48,
#   'low': 82.53,
#   'close': 83.42,
#   'volume': 114573900,
#   'change': -5.13,
#   'changePercent': -5.79,
#   'vwap': 86.25},
#  {'symbol': 'PLTR',
#   'date': '2025-02-28',
#   'open': 79.98,
#   'high': 85.18,
#   'low': 78.58,
#   'close': 84.92,
#   'volume': 125977400,
#   'change': 4.94,
#   'changePercent': 6.18,
#   'vwap': 82.17},
#  {'symbol': 'PLTR',
#   'date': '2025-02-27',
#   'open': 91.91,
#   'high': 93.62,
#   'low': 84.17,
#   'close': 84.77,
#   'volume': 99680500,
#   'change': -7.14,
#   'changePercent': -7.77,
#   'vwap': 88.62},
#  {'symbol': 'PLTR',
#   'date': '2025-02-26',
#   'open': 89.16,
#   'high': 91.69,
#   'low': 87.59,
#   'close': 89.31,
#   'volume': 94846200,
#   'change': 0.15,
#   'changePercent': 0.16824,
#   'vwap': 89.44},
#  {'symbol': 'PLTR',
#   'date': '2025-02-25',
#   'open': 90.65,
#   'high': 91.7,
#   'low': 85.25,
#   'close': 87.84,
#   'volume': 132626300,
#   'change': -2.81,
#   'changePercent': -3.1,
#   'vwap': 88.86},
#  {'symbol': 'PLTR',
#   'date': '2025-02-24',
#   'open': 95.88,
#   'high': 99.01,
#   'low': 89.3,
#   'close': 90.68,
#   'volume': 184485000,
#   'change': -5.2,
#   'changePercent': -5.42,
#   'vwap': 93.72},
#  {'symbol': 'PLTR',
#   'date': '2025-02-21',
#   'open': 107.68,
#   'high': 109.07,
#   'low': 100,
#   'close': 101.35,
#   'volume': 129063200,
#   'change': -6.33,
#   'changePercent': -5.88,
#   'vwap': 104.52},
#  {'symbol': 'PLTR',
#   'date': '2025-02-20',
#   'open': 102.91,
#   'high': 107.4,
#   'low': 95.8,
#   'close': 106.27,
#   'volume': 243093900,
#   'change': 3.36,
#   'changePercent': 3.26,
#   'vwap': 103.1},
#  {'symbol': 'PLTR',
#   'date': '2025-02-19',
#   'open': 123.86,
#   'high': 125.41,
#   'low': 108.56,
#   'close': 112.06,
#   'volume': 147487300,
#   'change': -11.8,
#   'changePercent': -9.53,
#   'vwap': 117.47},
#  {'symbol': 'PLTR',
#   'date': '2025-02-18',
#   'open': 120.94,
#   'high': 125,
#   'low': 118.43,
#   'close': 124.62,
#   'volume': 84227200,
#   'change': 3.68,
#   'changePercent': 3.04,
#   'vwap': 122.25},
#  {'symbol': 'PLTR',
#   'date': '2025-02-14',
#   'open': 117.9,
#   'high': 120.67,
#   'low': 116.8,
#   'close': 119.16,
#   'volume': 65528900,
#   'change': 1.26,
#   'changePercent': 1.07,
#   'vwap': 118.63},
#  {'symbol': 'PLTR',
#   'date': '2025-02-13',
#   'open': 117.31,
#   'high': 118.39,
#   'low': 115.15,
#   'close': 117.91,
#   'volume': 60027000,
#   'change': 0.6,
#   'changePercent': 0.51147,
#   'vwap': 117.19},
#  {'symbol': 'PLTR',
#   'date': '2025-02-12',
#   'open': 110.29,
#   'high': 117.59,
#   'low': 110,
#   'close': 117.39,
#   'volume': 75316900,
#   'change': 7.1,
#   'changePercent': 6.44,
#   'vwap': 113.82},
#  {'symbol': 'PLTR',
#   'date': '2025-02-11',
#   'open': 116.5,
#   'high': 118.66,
#   'low': 112.1,
#   'close': 112.62,
#   'volume': 94311700,
#   'change': -3.88,
#   'changePercent': -3.33,
#   'vwap': 114.97},
#  {'symbol': 'PLTR',
#   'date': '2025-02-10',
#   'open': 112.03,
#   'high': 116.76,
#   'low': 108.72,
#   'close': 116.65,
#   'volume': 99344700,
#   'change': 4.62,
#   'changePercent': 4.12,
#   'vwap': 113.88},
#  {'symbol': 'PLTR',
#   'date': '2025-02-07',
#   'open': 111.66,
#   'high': 116.3,
#   'low': 110.45,
#   'close': 110.85,
#   'volume': 143546364,
#   'change': -0.81,
#   'changePercent': -0.72542,
#   'vwap': 113.66},
#  {'symbol': 'PLTR',
#   'date': '2025-02-06',
#   'open': 101.09,
#   'high': 111.545,
#   'low': 100.26,
#   'close': 111.28,
#   'volume': 127705941,
#   'change': 10.19,
#   'changePercent': 10.08,
#   'vwap': 107.65},
#  {'symbol': 'PLTR',
#   'date': '2025-02-05',
#   'open': 101.78,
#   'high': 103.57,
#   'low': 99.32,
#   'close': 101.36,
#   'volume': 90307648,
#   'change': -0.42,
#   'changePercent': -0.41265,
#   'vwap': 101.23},
#  {'symbol': 'PLTR',
#   'date': '2025-02-04',
#   'open': 102.8,
#   'high': 106.91,
#   'low': 100.51,
#   'close': 103.83,
#   'volume': 229384405,
#   'change': 1.03,
#   'changePercent': 1,
#   'vwap': 103.62},
#  {'symbol': 'PLTR',
#   'date': '2025-02-03',
#   'open': 80.125,
#   'high': 84.25,
#   'low': 78.47,
#   'close': 83.74,
#   'volume': 126097917,
#   'change': 3.615,
#   'changePercent': 4.51,
#   'vwap': 87.32},
#  {'symbol': 'PLTR',
#   'date': '2025-01-31',
#   'open': 81,
#   'high': 85.22,
#   'low': 80.87,
#   'close': 82.49,
#   'volume': 78296383,
#   'change': 1.49,
#   'changePercent': 1.84,
#   'vwap': 83.81},
#  {'symbol': 'PLTR',
#   'date': '2025-01-30',
#   'open': 80.02,
#   'high': 81.8299,
#   'low': 79.38,
#   'close': 81.22,
#   'volume': 45696665,
#   'change': 1.2,
#   'changePercent': 1.5,
#   'vwap': 80.7},
#  {'symbol': 'PLTR',
#   'date': '2025-01-29',
#   'open': 79.95,
#   'high': 80.8199,
#   'low': 77.81,
#   'close': 79.76,
#   'volume': 48960318,
#   'change': -0.19,
#   'changePercent': -0.23765,
#   'vwap': 79.26},
#  {'symbol': 'PLTR',
#   'date': '2025-01-28',
#   'open': 75.54,
#   'high': 80.74,
#   'low': 74.04,
#   'close': 80.23,
#   'volume': 65644947,
#   'change': 4.69,
#   'changePercent': 6.21,
#   'vwap': 78.48},
#  {'symbol': 'PLTR',
#   'date': '2025-01-27',
#   'open': 74.07,
#   'high': 76.72,
#   'low': 72.67,
#   'close': 75.44,
#   'volume': 75686549,
#   'change': 1.37,
#   'changePercent': 1.85,
#   'vwap': 74.62},
#  {'symbol': 'PLTR',
#   'date': '2025-01-24',
#   'open': 79.05,
#   'high': 82.24,
#   'low': 78.4401,
#   'close': 78.98,
#   'volume': 77530380,
#   'change': -0.07,
#   'changePercent': -0.08855155,
#   'vwap': 80.37},
#  {'symbol': 'PLTR',
#   'date': '2025-01-23',
#   'open': 76.04,
#   'high': 79,
#   'low': 75.84,
#   'close': 78.98,
#   'volume': 55537753,
#   'change': 2.94,
#   'changePercent': 3.87,
#   'vwap': 77.78},
#  {'symbol': 'PLTR',
#   'date': '2025-01-22',
#   'open': 74.5,
#   'high': 77.16,
#   'low': 73.8,
#   'close': 76.87,
#   'volume': 65779896,
#   'change': 2.37,
#   'changePercent': 3.18,
#   'vwap': 75.92},
#  {'symbol': 'PLTR',
#   'date': '2025-01-21',
#   'open': 73.24,
#   'high': 73.6363,
#   'low': 70.6007,
#   'close': 73.07,
#   'volume': 54532577,
#   'change': -0.17,
#   'changePercent': -0.23211,
#   'vwap': 72.78},
#  {'symbol': 'PLTR',
#   'date': '2025-01-17',
#   'open': 70.9,
#   'high': 72.34,
#   'low': 69.95,
#   'close': 71.77,
#   'volume': 54412541,
#   'change': 0.87,
#   'changePercent': 1.23,
#   'vwap': 71.33},
#  {'symbol': 'PLTR',
#   'date': '2025-01-16',
#   'open': 69.08,
#   'high': 71.43,
#   'low': 68.36,
#   'close': 69.24,
#   'volume': 61651454,
#   'change': 0.16,
#   'changePercent': 0.23162,
#   'vwap': 69.99},
#  {'symbol': 'PLTR',
#   'date': '2025-01-15',
#   'open': 68.55,
#   'high': 68.85,
#   'low': 67.08,
#   'close': 68.14,
#   'volume': 55209867,
#   'change': -0.41,
#   'changePercent': -0.5981,
#   'vwap': 68.07},
#  {'symbol': 'PLTR',
#   'date': '2025-01-14',
#   'open': 67.18,
#   'high': 68.23,
#   'low': 65.19,
#   'close': 65.91,
#   'volume': 56593160,
#   'change': -1.27,
#   'changePercent': -1.89,
#   'vwap': 66.57},
#  {'symbol': 'PLTR',
#   'date': '2025-01-13',
#   'open': 64.29,
#   'high': 65.68,
#   'low': 63.4,
#   'close': 64.98,
#   'volume': 68534333,
#   'change': 0.69,
#   'changePercent': 1.07,
#   'vwap': 64.61},
#  {'symbol': 'PLTR',
#   'date': '2025-01-10',
#   'open': 66.01,
#   'high': 68.2,
#   'low': 65.04,
#   'close': 67.26,
#   'volume': 77372421,
#   'change': 1.25,
#   'changePercent': 1.89,
#   'vwap': 66.5},
#  {'symbol': 'PLTR',
#   'date': '2025-01-08',
#   'open': 68.12,
#   'high': 69.53,
#   'low': 66.51,
#   'close': 68.23,
#   'volume': 89721574,
#   'change': 0.11,
#   'changePercent': 0.16148,
#   'vwap': 68.04},
#  {'symbol': 'PLTR',
#   'date': '2025-01-07',
#   'open': 75.2,
#   'high': 75.39,
#   'low': 69.75,
#   'close': 69.99,
#   'volume': 91345786,
#   'change': -5.21,
#   'changePercent': -6.93,
#   'vwap': 71.63},
#  {'symbol': 'PLTR',
#   'date': '2025-01-06',
#   'open': 78.69,
#   'high': 80.06,
#   'low': 74.61,
#   'close': 75.92,
#   'volume': 105238305,
#   'change': -2.77,
#   'changePercent': -3.52,
#   'vwap': 76.97},
#  {'symbol': 'PLTR',
#   'date': '2025-01-03',
#   'open': 75.39,
#   'high': 79.98,
#   'low': 75.19,
#   'close': 79.89,
#   'volume': 61975477,
#   'change': 4.5,
#   'changePercent': 5.97,
#   'vwap': 78.63},
#  {'symbol': 'PLTR',
#   'date': '2025-01-02',
#   'open': 76.2,
#   'high': 76.53,
#   'low': 72.42,
#   'close': 75.19,
#   'volume': 72098910,
#   'change': -1.01,
#   'changePercent': -1.33,
#   'vwap': 74.49},
#  {'symbol': 'PLTR',
#   'date': '2024-12-31',
#   'open': 77.58,
#   'high': 77.9796,
#   'low': 73.65,
#   'close': 75.63,
#   'volume': 55783611,
#   'change': -1.95,
#   'changePercent': -2.51,
#   'vwap': 76.38},
#  {'symbol': 'PLTR',
#   'date': '2024-12-30',
#   'open': 77.04,
#   'high': 79.24,
#   'low': 76.11,
#   'close': 77.18,
#   'volume': 60461862,
#   'change': 0.14,
#   'changePercent': 0.18172,
#   'vwap': 77.68},
#  {'symbol': 'PLTR',
#   'date': '2024-12-27',
#   'open': 81.42,
#   'high': 82,
#   'low': 77.93,
#   'close': 79.08,
#   'volume': 66355350,
#   'change': -2.34,
#   'changePercent': -2.87,
#   'vwap': 79.14},
#  {'symbol': 'PLTR',
#   'date': '2024-12-26',
#   'open': 83.16,
#   'high': 83.49,
#   'low': 81.3,
#   'close': 82.14,
#   'volume': 60322097,
#   'change': -1.02,
#   'changePercent': -1.23,
#   'vwap': 82.3},
#  {'symbol': 'PLTR',
#   'date': '2024-12-24',
#   'open': 81.09,
#   'high': 84.7968,
#   'low': 81,
#   'close': 82.38,
#   'volume': 64955538,
#   'change': 1.29,
#   'changePercent': 1.59,
#   'vwap': 83.02},
#  {'symbol': 'PLTR',
#   'date': '2024-12-23',
#   'open': 80.65,
#   'high': 82.02,
#   'low': 77.41,
#   'close': 80.69,
#   'volume': 92041294,
#   'change': 0.04,
#   'changePercent': 0.04959702,
#   'vwap': 80.03},
#  {'symbol': 'PLTR',
#   'date': '2024-12-20',
#   'open': 72.64,
#   'high': 80.66,
#   'low': 71.5,
#   'close': 80.55,
#   'volume': 217699660,
#   'change': 7.91,
#   'changePercent': 10.89,
#   'vwap': 78.72},
#  {'symbol': 'PLTR',
#   'date': '2024-12-19',
#   'open': 73.99,
#   'high': 76.59,
#   'low': 73.37,
#   'close': 74.21,
#   'volume': 98979683,
#   'change': 0.22,
#   'changePercent': 0.29734,
#   'vwap': 74.8},
#  {'symbol': 'PLTR',
#   'date': '2024-12-18',
#   'open': 74.3,
#   'high': 77.6,
#   'low': 70.27,
#   'close': 71.51,
#   'volume': 107847403,
#   'change': -2.79,
#   'changePercent': -3.76,
#   'vwap': 74.89},
#  {'symbol': 'PLTR',
#   'date': '2024-12-17',
#   'open': 73.28,
#   'high': 75.32,
#   'low': 71.7,
#   'close': 74.39,
#   'volume': 74682107,
#   'change': 1.11,
#   'changePercent': 1.51,
#   'vwap': 73.86},
#  {'symbol': 'PLTR',
#   'date': '2024-12-16',
#   'open': 75.06,
#   'high': 77.82,
#   'low': 71.16,
#   'close': 75.75,
#   'volume': 124752710,
#   'change': 0.69,
#   'changePercent': 0.91926,
#   'vwap': 74.19},
#  {'symbol': 'PLTR',
#   'date': '2024-12-13',
#   'open': 73.49,
#   'high': 76.1,
#   'low': 72.45,
#   'close': 76.07,
#   'volume': 76036831,
#   'change': 2.58,
#   'changePercent': 3.51,
#   'vwap': 74.38},
#  {'symbol': 'PLTR',
#   'date': '2024-12-12',
#   'open': 72.3,
#   'high': 75.38,
#   'low': 71.9,
#   'close': 73.2,
#   'volume': 73722029,
#   'change': 0.9,
#   'changePercent': 1.24,
#   'vwap': 73.45},
#  {'symbol': 'PLTR',
#   'date': '2024-12-11',
#   'open': 72.98,
#   'high': 73,
#   'low': 68.07,
#   'close': 72.51,
#   'volume': 88832875,
#   'change': -0.47,
#   'changePercent': -0.64401,
#   'vwap': 70.84},
#  {'symbol': 'PLTR',
#   'date': '2024-12-10',
#   'open': 71.99,
#   'high': 75.56,
#   'low': 70.73,
#   'close': 70.89,
#   'volume': 89485783,
#   'change': -1.1,
#   'changePercent': -1.53,
#   'vwap': 73.02},
#  {'symbol': 'PLTR',
#   'date': '2024-12-09',
#   'open': 80.58,
#   'high': 80.91,
#   'low': 71.05,
#   'close': 72.46,
#   'volume': 167588326,
#   'change': -8.12,
#   'changePercent': -10.08,
#   'vwap': 75.09},
#  {'symbol': 'PLTR',
#   'date': '2024-12-06',
#   'open': 72.95,
#   'high': 76.82,
#   'low': 72.28,
#   'close': 76.34,
#   'volume': 93147056,
#   'change': 3.39,
#   'changePercent': 4.65,
#   'vwap': 75.57},
#  {'symbol': 'PLTR',
#   'date': '2024-12-05',
#   'open': 70.11,
#   'high': 72.98,
#   'low': 69.89,
#   'close': 71.87,
#   'volume': 66309879,
#   'change': 1.76,
#   'changePercent': 2.51,
#   'vwap': 71.71},
#  {'symbol': 'PLTR',
#   'date': '2024-12-04',
#   'open': 71.13,
#   'high': 71.18,
#   'low': 67.28,
#   'close': 69.85,
#   'volume': 85912331,
#   'change': -1.28,
#   'changePercent': -1.8,
#   'vwap': 69.42},
#  {'symbol': 'PLTR',
#   'date': '2024-12-03',
#   'open': 66.41,
#   'high': 71.37,
#   'low': 66.15,
#   'close': 70.96,
#   'volume': 100093638,
#   'change': 4.55,
#   'changePercent': 6.85,
#   'vwap': 69.99},
#  {'symbol': 'PLTR',
#   'date': '2024-12-02',
#   'open': 67.44,
#   'high': 67.88,
#   'low': 65.96,
#   'close': 66.39,
#   'volume': 46176781,
#   'change': -1.05,
#   'changePercent': -1.56,
#   'vwap': 66.73},
#  {'symbol': 'PLTR',
#   'date': '2024-11-29',
#   'open': 65.89,
#   'high': 67.16,
#   'low': 65.47,
#   'close': 67.08,
#   'volume': 29759044,
#   'change': 1.19,
#   'changePercent': 1.81,
#   'vwap': 66.61},
#  {'symbol': 'PLTR',
#   'date': '2024-11-27',
#   'open': 66.24,
#   'high': 67.56,
#   'low': 64.24,
#   'close': 66.05,
#   'volume': 53493615,
#   'change': -0.19,
#   'changePercent': -0.28684,
#   'vwap': 65.87},
#  {'symbol': 'PLTR',
#   'date': '2024-11-26',
#   'open': 64.57,
#   'high': 65.85,
#   'low': 63.89,
#   'close': 65.74,
#   'volume': 46852657,
#   'change': 1.17,
#   'changePercent': 1.81,
#   'vwap': 65.22},
#  {'symbol': 'PLTR',
#   'date': '2024-11-25',
#   'open': 66.9,
#   'high': 67.88,
#   'low': 64.08,
#   'close': 64.65,
#   'volume': 79893267,
#   'change': -2.25,
#   'changePercent': -3.36,
#   'vwap': 65.77},
#  {'symbol': 'PLTR',
#   'date': '2024-11-22',
#   'open': 61.6,
#   'high': 64.44,
#   'low': 61.37,
#   'close': 64.35,
#   'volume': 61381713,
#   'change': 2.75,
#   'changePercent': 4.46,
#   'vwap': 63.3},
#  {'symbol': 'PLTR',
#   'date': '2024-11-21',
#   'open': 62.04,
#   'high': 63.4,
#   'low': 60.895,
#   'close': 61.36,
#   'volume': 56336740,
#   'change': -0.68,
#   'changePercent': -1.1,
#   'vwap': 62.04},
#  {'symbol': 'PLTR',
#   'date': '2024-11-20',
#   'open': 62.59,
#   'high': 63.08,
#   'low': 59.96,
#   'close': 62.12,
#   'volume': 59182200,
#   'change': -0.47,
#   'changePercent': -0.75092,
#   'vwap': 61.42},
#  {'symbol': 'PLTR',
#   'date': '2024-11-19',
#   'open': 59.51,
#   'high': 63.01,
#   'low': 59.265,
#   'close': 62.98,
#   'volume': 75557817,
#   'change': 3.47,
#   'changePercent': 5.83,
#   'vwap': 61.37},
#  {'symbol': 'PLTR',
#   'date': '2024-11-18',
#   'open': 64.92,
#   'high': 64.92,
#   'low': 58.85,
#   'close': 61.26,
#   'volume': 137877641,
#   'change': -3.66,
#   'changePercent': -5.64,
#   'vwap': 62.4875},
#  {'symbol': 'PLTR',
#   'date': '2024-11-15',
#   'open': 61.01,
#   'high': 66,
#   'low': 60.91,
#   'close': 65.77,
#   'volume': 155280400,
#   'change': 4.76,
#   'changePercent': 7.8,
#   'vwap': 63.4225},
#  {'symbol': 'PLTR',
#   'date': '2024-11-14',
#   'open': 61.05,
#   'high': 61.17,
#   'low': 58.53,
#   'close': 59.18,
#   'volume': 59968240,
#   'change': -1.87,
#   'changePercent': -3.06,
#   'vwap': 59.9825},
#  {'symbol': 'PLTR',
#   'date': '2024-11-13',
#   'open': 61.52,
#   'high': 63.39,
#   'low': 59.85,
#   'close': 60.7,
#   'volume': 85937400,
#   'change': -0.82,
#   'changePercent': -1.33,
#   'vwap': 61.365},
#  {'symbol': 'PLTR',
#   'date': '2024-11-12',
#   'open': 59.01,
#   'high': 60.09,
#   'low': 58.57,
#   'close': 59.85,
#   'volume': 59061338,
#   'change': 0.84,
#   'changePercent': 1.42,
#   'vwap': 59.38},
#  {'symbol': 'PLTR',
#   'date': '2024-11-11',
#   'open': 60.13,
#   'high': 62.08,
#   'low': 58.69,
#   'close': 60.24,
#   'volume': 108357800,
#   'change': 0.1075,
#   'changePercent': 0.18294,
#   'vwap': 60.285},
#  {'symbol': 'PLTR',
#   'date': '2024-11-08',
#   'open': 55.57,
#   'high': 58.48,
#   'low': 55.3,
#   'close': 58.39,
#   'volume': 84124034,
#   'change': 2.82,
#   'changePercent': 5.07,
#   'vwap': 56.935},
#  {'symbol': 'PLTR',
#   'date': '2024-11-07',
#   'open': 55.82,
#   'high': 56.47,
#   'low': 53.55,
#   'close': 55.88,
#   'volume': 121591200,
#   'change': 0.06,
#   'changePercent': 0.10749,
#   'vwap': 55.43},
#  {'symbol': 'PLTR',
#   'date': '2024-11-06',
#   'open': 53.44,
#   'high': 55.69,
#   'low': 51.61,
#   'close': 55.53,
#   'volume': 114255943,
#   'change': 2.09,
#   'changePercent': 3.91,
#   'vwap': 54.0675},
#  {'symbol': 'PLTR',
#   'date': '2024-11-05',
#   'open': 47.86,
#   'high': 51.58,
#   'low': 46.86,
#   'close': 51.13,
#   'volume': 208868200,
#   'change': 3.27,
#   'changePercent': 6.83,
#   'vwap': 49.3575},
#  {'symbol': 'PLTR',
#   'date': '2024-11-04',
#   'open': 41.08,
#   'high': 42.04,
#   'low': 41.03,
#   'close': 41.41,
#   'volume': 75413300,
#   'change': 0.33,
#   'changePercent': 0.80331,
#   'vwap': 41.39},
#  {'symbol': 'PLTR',
#   'date': '2024-11-01',
#   'open': 41.93,
#   'high': 42.57,
#   'low': 41.59,
#   'close': 41.92,
#   'volume': 33722521,
#   'change': -0.01,
#   'changePercent': -0.02384927,
#   'vwap': 42.0025},
#  {'symbol': 'PLTR',
#   'date': '2024-10-31',
#   'open': 42.79,
#   'high': 43.32,
#   'low': 40.9,
#   'close': 41.56,
#   'volume': 50973400,
#   'change': -1.23,
#   'changePercent': -2.87,
#   'vwap': 42.1425},
#  {'symbol': 'PLTR',
#   'date': '2024-10-30',
#   'open': 44.58,
#   'high': 44.8,
#   'low': 43.61,
#   'close': 43.69,
#   'volume': 31309232,
#   'change': -0.89,
#   'changePercent': -2,
#   'vwap': 44.17},
#  {'symbol': 'PLTR',
#   'date': '2024-10-29',
#   'open': 44.9,
#   'high': 45.07,
#   'low': 44.04,
#   'close': 44.93,
#   'volume': 26154712,
#   'change': 0.03,
#   'changePercent': 0.06681514,
#   'vwap': 44.735},
#  {'symbol': 'PLTR',
#   'date': '2024-10-28',
#   'open': 45.05,
#   'high': 45.14,
#   'low': 44.68,
#   'close': 44.97,
#   'volume': 36729700,
#   'change': -0.08,
#   'changePercent': -0.17758,
#   'vwap': 44.96},
#  {'symbol': 'PLTR',
#   'date': '2024-10-25',
#   'open': 43.85,
#   'high': 45.07,
#   'low': 43.65,
#   'close': 44.86,
#   'volume': 50416500,
#   'change': 1.01,
#   'changePercent': 2.3,
#   'vwap': 44.3575},
#  {'symbol': 'PLTR',
#   'date': '2024-10-24',
#   'open': 42.89,
#   'high': 43.73,
#   'low': 42.66,
#   'close': 43.56,
#   'volume': 34079600,
#   'change': 0.67,
#   'changePercent': 1.56,
#   'vwap': 43.21},
#  {'symbol': 'PLTR',
#   'date': '2024-10-23',
#   'open': 42.85,
#   'high': 43.68,
#   'low': 42.06,
#   'close': 42.59,
#   'volume': 35647000,
#   'change': -0.26,
#   'changePercent': -0.60677,
#   'vwap': 42.795},
#  {'symbol': 'PLTR',
#   'date': '2024-10-22',
#   'open': 42.69,
#   'high': 43.49,
#   'low': 42.3,
#   'close': 42.94,
#   'volume': 27830734,
#   'change': 0.25,
#   'changePercent': 0.58562,
#   'vwap': 42.855},
#  {'symbol': 'PLTR',
#   'date': '2024-10-21',
#   'open': 42.86,
#   'high': 43.4,
#   'low': 42.41,
#   'close': 42.7,
#   'volume': 30719800,
#   'change': -0.16,
#   'changePercent': -0.37331,
#   'vwap': 42.8425},
#  {'symbol': 'PLTR',
#   'date': '2024-10-18',
#   'open': 42.02,
#   'high': 42.99,
#   'low': 41.65,
#   'close': 42.97,
#   'volume': 33969020,
#   'change': 0.955,
#   'changePercent': 2.26,
#   'vwap': 42.4075},
#  {'symbol': 'PLTR',
#   'date': '2024-10-17',
#   'open': 42.15,
#   'high': 42.7,
#   'low': 41.61,
#   'close': 42,
#   'volume': 34028414,
#   'change': -0.15,
#   'changePercent': -0.35587,
#   'vwap': 42.115},
#  {'symbol': 'PLTR',
#   'date': '2024-10-16',
#   'open': 42.4,
#   'high': 42.49,
#   'low': 40.36,
#   'close': 41.93,
#   'volume': 59157938,
#   'change': -0.47,
#   'changePercent': -1.11,
#   'vwap': 41.795},
#  {'symbol': 'PLTR',
#   'date': '2024-10-15',
#   'open': 43.48,
#   'high': 43.68,
#   'low': 41.52,
#   'close': 42.43,
#   'volume': 48297000,
#   'change': -1.05,
#   'changePercent': -2.41,
#   'vwap': 42.7775},
#  {'symbol': 'PLTR',
#   'date': '2024-10-14',
#   'open': 43.72,
#   'high': 44.39,
#   'low': 43.28,
#   'close': 43.4,
#   'volume': 41010910,
#   'change': -0.32,
#   'changePercent': -0.73193,
#   'vwap': 43.6975},
#  {'symbol': 'PLTR',
#   'date': '2024-10-11',
#   'open': 43.4,
#   'high': 44.38,
#   'low': 42.62,
#   'close': 43.51,
#   'volume': 66206900,
#   'change': 0.11,
#   'changePercent': 0.25346,
#   'vwap': 43.4775},
#  {'symbol': 'PLTR',
#   'date': '2024-10-10',
#   'open': 42.92,
#   'high': 43.88,
#   'low': 42.41,
#   'close': 43.52,
#   'volume': 62516314,
#   'change': 0.6,
#   'changePercent': 1.4,
#   'vwap': 43.1825},
#  {'symbol': 'PLTR',
#   'date': '2024-10-09',
#   'open': 41.55,
#   'high': 43.34,
#   'low': 41.21,
#   'close': 43.13,
#   'volume': 86404700,
#   'change': 1.58,
#   'changePercent': 3.8,
#   'vwap': 42.3075},
#  {'symbol': 'PLTR',
#   'date': '2024-10-08',
#   'open': 39.29,
#   'high': 41.49,
#   'low': 39.02,
#   'close': 41.45,
#   'volume': 62542945,
#   'change': 2.16,
#   'changePercent': 5.5,
#   'vwap': 40.3125},
#  {'symbol': 'PLTR',
#   'date': '2024-10-07',
#   'open': 39.9,
#   'high': 40.15,
#   'low': 38.78,
#   'close': 38.89,
#   'volume': 44124800,
#   'change': -1.01,
#   'changePercent': -2.53,
#   'vwap': 39.43},
#  {'symbol': 'PLTR',
#   'date': '2024-10-04',
#   'open': 39.65,
#   'high': 40.29,
#   'low': 39.4,
#   'close': 40.01,
#   'volume': 62657545,
#   'change': 0.36,
#   'changePercent': 0.90794,
#   'vwap': 39.8375},
#  {'symbol': 'PLTR',
#   'date': '2024-10-03',
#   'open': 37.45,
#   'high': 39.29,
#   'low': 37.37,
#   'close': 39.24,
#   'volume': 57196445,
#   'change': 1.79,
#   'changePercent': 4.78,
#   'vwap': 38.3375},
#  {'symbol': 'PLTR',
#   'date': '2024-10-02',
#   'open': 36.3,
#   'high': 37.68,
#   'low': 36.15,
#   'close': 37.49,
#   'volume': 34988906,
#   'change': 1.19,
#   'changePercent': 3.28,
#   'vwap': 36.905},
#  {'symbol': 'PLTR',
#   'date': '2024-10-01',
#   'open': 37.21,
#   'high': 37.56,
#   'low': 36.05,
#   'close': 36.46,
#   'volume': 52858036,
#   'change': -0.75,
#   'changePercent': -2.02,
#   'vwap': 36.82},
#  {'symbol': 'PLTR',
#   'date': '2024-09-30',
#   'open': 36.58,
#   'high': 37.32,
#   'low': 36.15,
#   'close': 37.2,
#   'volume': 42223553,
#   'change': 0.62,
#   'changePercent': 1.69,
#   'vwap': 36.8125},
#  {'symbol': 'PLTR',
#   'date': '2024-09-27',
#   'open': 36.91,
#   'high': 37.47,
#   'low': 36.59,
#   'close': 36.84,
#   'volume': 43219122,
#   'change': -0.07,
#   'changePercent': -0.18965,
#   'vwap': 36.9525},
#  {'symbol': 'PLTR',
#   'date': '2024-09-26',
#   'open': 37.26,
#   'high': 37.44,
#   'low': 36.6,
#   'close': 37.1,
#   'volume': 48602000,
#   'change': -0.16,
#   'changePercent': -0.42941,
#   'vwap': 37.1},
#  {'symbol': 'PLTR',
#   'date': '2024-09-25',
#   'open': 36.89,
#   'high': 37.18,
#   'low': 36.38,
#   'close': 37.12,
#   'volume': 46511724,
#   'change': 0.23,
#   'changePercent': 0.62348,
#   'vwap': 36.8925},
#  {'symbol': 'PLTR',
#   'date': '2024-09-24',
#   'open': 37.97,
#   'high': 37.98,
#   'low': 36.43,
#   'close': 36.9,
#   'volume': 79519248,
#   'change': -1.07,
#   'changePercent': -2.82,
#   'vwap': 37.32},
#  {'symbol': 'PLTR',
#   'date': '2024-09-23',
#   'open': 36.86,
#   'high': 38.19,
#   'low': 36.57,
#   'close': 37.95,
#   'volume': 79460737,
#   'change': 1.09,
#   'changePercent': 2.96,
#   'vwap': 37.3925},
#  {'symbol': 'PLTR',
#   'date': '2024-09-20',
#   'open': 36.01,
#   'high': 37.29,
#   'low': 35.71,
#   'close': 37.2,
#   'volume': 450290538,
#   'change': 1.19,
#   'changePercent': 3.3,
#   'vwap': 36.5525},
#  {'symbol': 'PLTR',
#   'date': '2024-09-19',
#   'open': 37,
#   'high': 37.35,
#   'low': 36.2,
#   'close': 36.83,
#   'volume': 59882041,
#   'change': -0.17,
#   'changePercent': -0.45946,
#   'vwap': 36.845},
#  {'symbol': 'PLTR',
#   'date': '2024-09-18',
#   'open': 35.9,
#   'high': 37.11,
#   'low': 35.87,
#   'close': 36.38,
#   'volume': 66279800,
#   'change': 0.48,
#   'changePercent': 1.34,
#   'vwap': 36.315},
#  {'symbol': 'PLTR',
#   'date': '2024-09-17',
#   'open': 37,
#   'high': 37.05,
#   'low': 35.87,
#   'close': 36.45,
#   'volume': 64461800,
#   'change': -0.55,
#   'changePercent': -1.49,
#   'vwap': 36.5925},
#  {'symbol': 'PLTR',
#   'date': '2024-09-16',
#   'open': 35.78,
#   'high': 36.92,
#   'low': 35.56,
#   'close': 36.31,
#   'volume': 74767329,
#   'change': 0.53,
#   'changePercent': 1.48,
#   'vwap': 36.1425},
#  {'symbol': 'PLTR',
#   'date': '2024-09-13',
#   'open': 34.97,
#   'high': 36.01,
#   'low': 34.89,
#   'close': 35.59,
#   'volume': 49727200,
#   'change': 0.62,
#   'changePercent': 1.77,
#   'vwap': 35.365},
#  {'symbol': 'PLTR',
#   'date': '2024-09-12',
#   'open': 34.86,
#   'high': 35.4,
#   'low': 34.53,
#   'close': 34.91,
#   'volume': 54391843,
#   'change': 0.05,
#   'changePercent': 0.14343,
#   'vwap': 34.925},
#  {'symbol': 'PLTR',
#   'date': '2024-09-11',
#   'open': 34.01,
#   'high': 34.87,
#   'low': 33.62,
#   'close': 34.85,
#   'volume': 68302300,
#   'change': 0.84,
#   'changePercent': 2.47,
#   'vwap': 34.3375},
#  {'symbol': 'PLTR',
#   'date': '2024-09-10',
#   'open': 34.81,
#   'high': 35.2,
#   'low': 33.71,
#   'close': 34.76,
#   'volume': 91721000,
#   'change': -0.05,
#   'changePercent': -0.14364,
#   'vwap': 34.62},
#  {'symbol': 'PLTR',
#   'date': '2024-09-09',
#   'open': 32.7,
#   'high': 34.7,
#   'low': 32.47,
#   'close': 34.6,
#   'volume': 140582500,
#   'change': 1.9,
#   'changePercent': 5.81,
#   'vwap': 33.6175},
#  {'symbol': 'PLTR',
#   'date': '2024-09-06',
#   'open': 30.6,
#   'high': 31.04,
#   'low': 29.5,
#   'close': 30.33,
#   'volume': 50946800,
#   'change': -0.27,
#   'changePercent': -0.88235,
#   'vwap': 30.3675},
#  {'symbol': 'PLTR',
#   'date': '2024-09-05',
#   'open': 30.24,
#   'high': 30.74,
#   'low': 30.01,
#   'close': 30.16,
#   'volume': 24012331,
#   'change': -0.08,
#   'changePercent': -0.26455,
#   'vwap': 30.2875},
#  {'symbol': 'PLTR',
#   'date': '2024-09-04',
#   'open': 30,
#   'high': 30.85,
#   'low': 29.31,
#   'close': 30.59,
#   'volume': 33419500,
#   'change': 0.59,
#   'changePercent': 1.97,
#   'vwap': 30.1875},
#  {'symbol': 'PLTR',
#   'date': '2024-09-03',
#   'open': 31.35,
#   'high': 31.59,
#   'low': 30.17,
#   'close': 30.51,
#   'volume': 34531600,
#   'change': -0.84,
#   'changePercent': -2.68,
#   'vwap': 30.905},
#  {'symbol': 'PLTR',
#   'date': '2024-08-30',
#   'open': 31.05,
#   'high': 31.5,
#   'low': 30.7,
#   'close': 31.48,
#   'volume': 42388023,
#   'change': 0.43,
#   'changePercent': 1.38,
#   'vwap': 31.1825},
#  {'symbol': 'PLTR',
#   'date': '2024-08-29',
#   'open': 30.65,
#   'high': 31.82,
#   'low': 30.48,
#   'close': 31,
#   'volume': 39733000,
#   'change': 0.35,
#   'changePercent': 1.14,
#   'vwap': 30.9875},
#  {'symbol': 'PLTR',
#   'date': '2024-08-28',
#   'open': 30.62,
#   'high': 30.8,
#   'low': 29.75,
#   'close': 30.36,
#   'volume': 33961400,
#   'change': -0.26,
#   'changePercent': -0.84912,
#   'vwap': 30.3825},
#  {'symbol': 'PLTR',
#   'date': '2024-08-27',
#   'open': 30.55,
#   'high': 31.12,
#   'low': 30.38,
#   'close': 30.84,
#   'volume': 23541300,
#   'change': 0.29,
#   'changePercent': 0.94926,
#   'vwap': 30.7225},
#  {'symbol': 'PLTR',
#   'date': '2024-08-26',
#   'open': 31.43,
#   'high': 31.74,
#   'low': 30.79,
#   'close': 30.85,
#   'volume': 35283625,
#   'change': -0.58,
#   'changePercent': -1.85,
#   'vwap': 31.2025},
#  {'symbol': 'PLTR',
#   'date': '2024-08-23',
#   'open': 31.99,
#   'high': 32.55,
#   'low': 31.62,
#   'close': 31.78,
#   'volume': 34121200,
#   'change': -0.21,
#   'changePercent': -0.65646,
#   'vwap': 31.985},
#  {'symbol': 'PLTR',
#   'date': '2024-08-22',
#   'open': 32.55,
#   'high': 33.13,
#   'low': 31.85,
#   'close': 31.92,
#   'volume': 43522223,
#   'change': -0.63,
#   'changePercent': -1.94,
#   'vwap': 32.3625},
#  {'symbol': 'PLTR',
#   'date': '2024-08-21',
#   'open': 32.32,
#   'high': 32.67,
#   'low': 31.97,
#   'close': 32.54,
#   'volume': 38147600,
#   'change': 0.22,
#   'changePercent': 0.68069,
#   'vwap': 32.375},
#  {'symbol': 'PLTR',
#   'date': '2024-08-20',
#   'open': 32.5,
#   'high': 32.72,
#   'low': 31.63,
#   'close': 32.32,
#   'volume': 40783010,
#   'change': -0.18,
#   'changePercent': -0.55385,
#   'vwap': 32.2925},
#  {'symbol': 'PLTR',
#   'date': '2024-08-19',
#   'open': 32.42,
#   'high': 32.59,
#   'low': 31.81,
#   'close': 32.5,
#   'volume': 52353641,
#   'change': 0.08,
#   'changePercent': 0.24676,
#   'vwap': 32.33},
#  {'symbol': 'PLTR',
#   'date': '2024-08-16',
#   'open': 31.04,
#   'high': 32.75,
#   'low': 30.98,
#   'close': 32.08,
#   'volume': 64870638,
#   'change': 1.04,
#   'changePercent': 3.35,
#   'vwap': 31.7125},
#  {'symbol': 'PLTR',
#   'date': '2024-08-15',
#   'open': 31.31,
#   'high': 31.5,
#   'low': 30.83,
#   'close': 31.22,
#   'volume': 43407612,
#   'change': -0.09,
#   'changePercent': -0.28745,
#   'vwap': 31.215},
#  {'symbol': 'PLTR',
#   'date': '2024-08-14',
#   'open': 30.62,
#   'high': 31.37,
#   'low': 30.33,
#   'close': 31,
#   'volume': 49885641,
#   'change': 0.38,
#   'changePercent': 1.24,
#   'vwap': 30.83},
#  {'symbol': 'PLTR',
#   'date': '2024-08-13',
#   'open': 29.79,
#   'high': 30.85,
#   'low': 29.56,
#   'close': 30.39,
#   'volume': 57294206,
#   'change': 0.6013,
#   'changePercent': 2.01,
#   'vwap': 30.1475},
#  {'symbol': 'PLTR',
#   'date': '2024-08-12',
#   'open': 30.22,
#   'high': 31.2,
#   'low': 29.27,
#   'close': 29.38,
#   'volume': 67890322,
#   'change': -0.84,
#   'changePercent': -2.78,
#   'vwap': 30.0175},
#  {'symbol': 'PLTR',
#   'date': '2024-08-09',
#   'open': 29.28,
#   'high': 30.36,
#   'low': 29.1,
#   'close': 30.01,
#   'volume': 88131106,
#   'change': 0.73,
#   'changePercent': 2.49,
#   'vwap': 29.6875},
#  {'symbol': 'PLTR',
#   'date': '2024-08-08',
#   'open': 27.04,
#   'high': 29.38,
#   'low': 26.69,
#   'close': 29.28,
#   'volume': 96892918,
#   'change': 2.24,
#   'changePercent': 8.28,
#   'vwap': 28.0975},
#  {'symbol': 'PLTR',
#   'date': '2024-08-07',
#   'open': 27.07,
#   'high': 28.36,
#   'low': 26.24,
#   'close': 26.32,
#   'volume': 75975400,
#   'change': -0.75,
#   'changePercent': -2.77,
#   'vwap': 26.9975},
#  {'symbol': 'PLTR',
#   'date': '2024-08-06',
#   'open': 27.05,
#   'high': 27.42,
#   'low': 25.57,
#   'close': 26.59,
#   'volume': 99622700,
#   'change': -0.46,
#   'changePercent': -1.7,
#   'vwap': 26.6575},
#  {'symbol': 'PLTR',
#   'date': '2024-08-05',
#   'open': 21.74,
#   'high': 24.42,
#   'low': 21.23,
#   'close': 24.09,
#   'volume': 88023500,
#   'change': 2.35,
#   'changePercent': 10.81,
#   'vwap': 22.87},
#  {'symbol': 'PLTR',
#   'date': '2024-08-02',
#   'open': 24.75,
#   'high': 24.87,
#   'low': 23.75,
#   'close': 24.74,
#   'volume': 56092600,
#   'change': -0.01,
#   'changePercent': -0.04040404,
#   'vwap': 24.5275},
#  {'symbol': 'PLTR',
#   'date': '2024-08-01',
#   'open': 27.02,
#   'high': 27.54,
#   'low': 25.83,
#   'close': 26.08,
#   'volume': 31189607,
#   'change': -0.94,
#   'changePercent': -3.48,
#   'vwap': 26.6175},
#  {'symbol': 'PLTR',
#   'date': '2024-07-31',
#   'open': 27.02,
#   'high': 27.39,
#   'low': 26.88,
#   'close': 26.89,
#   'volume': 29111605,
#   'change': -0.13,
#   'changePercent': -0.48113,
#   'vwap': 27.045},
#  {'symbol': 'PLTR',
#   'date': '2024-07-30',
#   'open': 27.25,
#   'high': 27.44,
#   'low': 25.89,
#   'close': 26.37,
#   'volume': 31819905,
#   'change': -0.88,
#   'changePercent': -3.23,
#   'vwap': 26.7375},
#  {'symbol': 'PLTR',
#   'date': '2024-07-29',
#   'open': 27.56,
#   'high': 27.8,
#   'low': 26.73,
#   'close': 27.08,
#   'volume': 26038842,
#   'change': -0.48,
#   'changePercent': -1.74,
#   'vwap': 27.2925},
#  {'symbol': 'PLTR',
#   'date': '2024-07-26',
#   'open': 27,
#   'high': 27.34,
#   'low': 26.77,
#   'close': 27.18,
#   'volume': 27432224,
#   'change': 0.18,
#   'changePercent': 0.66667,
#   'vwap': 27.0725},
#  {'symbol': 'PLTR',
#   'date': '2024-07-25',
#   'open': 26.04,
#   'high': 27.29,
#   'low': 25.42,
#   'close': 26.63,
#   'volume': 45474613,
#   'change': 0.59,
#   'changePercent': 2.27,
#   'vwap': 26.345},
#  {'symbol': 'PLTR',
#   'date': '2024-07-24',
#   'open': 28.44,
#   'high': 28.69,
#   'low': 26.58,
#   'close': 26.6,
#   'volume': 49004105,
#   'change': -1.84,
#   'changePercent': -6.47,
#   'vwap': 27.5775},
#  {'symbol': 'PLTR',
#   'date': '2024-07-23',
#   'open': 28.34,
#   'high': 29.19,
#   'low': 28.31,
#   'close': 28.81,
#   'volume': 31134300,
#   'change': 0.47,
#   'changePercent': 1.66,
#   'vwap': 28.6625},
#  {'symbol': 'PLTR',
#   'date': '2024-07-22',
#   'open': 28.93,
#   'high': 28.97,
#   'low': 27.69,
#   'close': 28.46,
#   'volume': 38037812,
#   'change': -0.47,
#   'changePercent': -1.62,
#   'vwap': 28.5125},
#  {'symbol': 'PLTR',
#   'date': '2024-07-19',
#   'open': 28.31,
#   'high': 29.6,
#   'low': 28.27,
#   'close': 28.58,
#   'volume': 49581636,
#   'change': 0.27,
#   'changePercent': 0.95373,
#   'vwap': 28.69},
#  {'symbol': 'PLTR',
#   'date': '2024-07-18',
#   'open': 28.42,
#   'high': 29.83,
#   'low': 28.15,
#   'close': 28.64,
#   'volume': 76485561,
#   'change': 0.22,
#   'changePercent': 0.7741,
#   'vwap': 28.76},
#  {'symbol': 'PLTR',
#   'date': '2024-07-17',
#   'open': 28,
#   'high': 28.87,
#   'low': 27.6,
#   'close': 28.22,
#   'volume': 45203461,
#   'change': 0.22,
#   'changePercent': 0.78571,
#   'vwap': 28.1725},
#  {'symbol': 'PLTR',
#   'date': '2024-07-16',
#   'open': 28.18,
#   'high': 28.84,
#   'low': 27.47,
#   'close': 28.67,
#   'volume': 59330683,
#   'change': 0.49,
#   'changePercent': 1.74,
#   'vwap': 28.29},
#  {'symbol': 'PLTR',
#   'date': '2024-07-15',
#   'open': 28.42,
#   'high': 29.3,
#   'low': 27.9,
#   'close': 28.67,
#   'volume': 49186345,
#   'change': 0.25,
#   'changePercent': 0.87966,
#   'vwap': 28.5725},
#  {'symbol': 'PLTR',
#   'date': '2024-07-12',
#   'open': 27.32,
#   'high': 28.13,
#   'low': 27.28,
#   'close': 28.07,
#   'volume': 30760268,
#   'change': 0.75,
#   'changePercent': 2.75,
#   'vwap': 27.7},
#  {'symbol': 'PLTR',
#   'date': '2024-07-11',
#   'open': 28.49,
#   'high': 28.59,
#   'low': 26.9,
#   'close': 27.64,
#   'volume': 61546057,
#   'change': -0.85,
#   'changePercent': -2.98,
#   'vwap': 27.905},
#  {'symbol': 'PLTR',
#   'date': '2024-07-10',
#   'open': 27.5,
#   'high': 28.47,
#   'low': 27.37,
#   'close': 28.42,
#   'volume': 43231028,
#   'change': 0.92,
#   'changePercent': 3.35,
#   'vwap': 27.94},
#  {'symbol': 'PLTR',
#   'date': '2024-07-09',
#   'open': 27.93,
#   'high': 28.38,
#   'low': 27.23,
#   'close': 27.39,
#   'volume': 53226526,
#   'change': -0.54,
#   'changePercent': -1.93,
#   'vwap': 27.7325},
#  {'symbol': 'PLTR',
#   'date': '2024-07-08',
#   'open': 27.93,
#   'high': 27.99,
#   'low': 26.84,
#   'close': 27.7,
#   'volume': 59611163,
#   'change': -0.23,
#   'changePercent': -0.82349,
#   'vwap': 27.615},
#  {'symbol': 'PLTR',
#   'date': '2024-07-05',
#   'open': 26,
#   'high': 27.25,
#   'low': 25.98,
#   'close': 27.23,
#   'volume': 46703729,
#   'change': 1.23,
#   'changePercent': 4.73,
#   'vwap': 26.615},
#  {'symbol': 'PLTR',
#   'date': '2024-07-03',
#   'open': 25.96,
#   'high': 26.27,
#   'low': 25.76,
#   'close': 25.85,
#   'volume': 18433843,
#   'change': -0.11,
#   'changePercent': -0.42373,
#   'vwap': 25.96},
#  {'symbol': 'PLTR',
#   'date': '2024-07-02',
#   'open': 25.84,
#   'high': 26.43,
#   'low': 25.75,
#   'close': 25.83,
#   'volume': 32148242,
#   'change': -0.01,
#   'changePercent': -0.03869969,
#   'vwap': 25.9625},
#  {'symbol': 'PLTR',
#   'date': '2024-07-01',
#   'open': 25.48,
#   'high': 26.02,
#   'low': 25.14,
#   'close': 25.88,
#   'volume': 33167921,
#   'change': 0.4,
#   'changePercent': 1.57,
#   'vwap': 25.63},
#  {'symbol': 'PLTR',
#   'date': '2024-06-28',
#   'open': 25.28,
#   'high': 25.57,
#   'low': 25.03,
#   'close': 25.33,
#   'volume': 38886441,
#   'change': 0.05,
#   'changePercent': 0.19778,
#   'vwap': 25.3025},
#  {'symbol': 'PLTR',
#   'date': '2024-06-27',
#   'open': 24.1,
#   'high': 25.4,
#   'low': 24.05,
#   'close': 25.22,
#   'volume': 37882859,
#   'change': 1.12,
#   'changePercent': 4.65,
#   'vwap': 24.6925},
#  {'symbol': 'PLTR',
#   'date': '2024-06-26',
#   'open': 24.47,
#   'high': 24.66,
#   'low': 24.03,
#   'close': 24.1,
#   'volume': 24331377,
#   'change': -0.37,
#   'changePercent': -1.51,
#   'vwap': 24.315},
#  {'symbol': 'PLTR',
#   'date': '2024-06-25',
#   'open': 24.16,
#   'high': 24.63,
#   'low': 23.92,
#   'close': 24.56,
#   'volume': 29657245,
#   'change': 0.4,
#   'changePercent': 1.66,
#   'vwap': 24.3175},
#  {'symbol': 'PLTR',
#   'date': '2024-06-24',
#   'open': 23.44,
#   'high': 24.39,
#   'low': 23.3,
#   'close': 24.16,
#   'volume': 36477408,
#   'change': 0.72,
#   'changePercent': 3.07,
#   'vwap': 23.8225},
#  {'symbol': 'PLTR',
#   'date': '2024-06-21',
#   'open': 24.71,
#   'high': 26.09,
#   'low': 23.53,
#   'close': 23.84,
#   'volume': 69981578,
#   'change': -0.87,
#   'changePercent': -3.52,
#   'vwap': 24.5425},
#  {'symbol': 'PLTR',
#   'date': '2024-06-20',
#   'open': 26.44,
#   'high': 26.57,
#   'low': 25.16,
#   'close': 25.56,
#   'volume': 66734955,
#   'change': -0.88,
#   'changePercent': -3.33,
#   'vwap': 25.9325},
#  {'symbol': 'PLTR',
#   'date': '2024-06-18',
#   'open': 25.15,
#   'high': 26.03,
#   'low': 24.83,
#   'close': 25.82,
#   'volume': 54458580,
#   'change': 0.67,
#   'changePercent': 2.66,
#   'vwap': 25.4575},
#  {'symbol': 'PLTR',
#   'date': '2024-06-17',
#   'open': 23.47,
#   'high': 25.06,
#   'low': 23.45,
#   'close': 25.02,
#   'volume': 54294062,
#   'change': 1.55,
#   'changePercent': 6.6,
#   'vwap': 24.25},
#  {'symbol': 'PLTR',
#   'date': '2024-06-14',
#   'open': 23.15,
#   'high': 23.72,
#   'low': 22.84,
#   'close': 23.57,
#   'volume': 26618284,
#   'change': 0.42,
#   'changePercent': 1.81,
#   'vwap': 23.32},
#  {'symbol': 'PLTR',
#   'date': '2024-06-13',
#   'open': 23.85,
#   'high': 24.14,
#   'low': 23.15,
#   'close': 23.27,
#   'volume': 26035051,
#   'change': -0.58,
#   'changePercent': -2.43,
#   'vwap': 23.6025},
#  {'symbol': 'PLTR',
#   'date': '2024-06-12',
#   'open': 24.2,
#   'high': 24.33,
#   'low': 23.57,
#   'close': 23.77,
#   'volume': 38542724,
#   'change': -0.43,
#   'changePercent': -1.78,
#   'vwap': 23.9675},
#  {'symbol': 'PLTR',
#   'date': '2024-06-11',
#   'open': 23.06,
#   'high': 23.95,
#   'low': 22.89,
#   'close': 23.85,
#   'volume': 30601852,
#   'change': 0.79,
#   'changePercent': 3.43,
#   'vwap': 23.4375},
#  {'symbol': 'PLTR',
#   'date': '2024-06-10',
#   'open': 22.75,
#   'high': 23.16,
#   'low': 22.66,
#   'close': 23.13,
#   'volume': 31509278,
#   'change': 0.38,
#   'changePercent': 1.67,
#   'vwap': 22.925},
#  {'symbol': 'PLTR',
#   'date': '2024-06-07',
#   'open': 23.24,
#   'high': 23.57,
#   'low': 23.06,
#   'close': 23.31,
#   'volume': 37149877,
#   'change': 0.07,
#   'changePercent': 0.3012,
#   'vwap': 23.295},
#  {'symbol': 'PLTR',
#   'date': '2024-06-06',
#   'open': 22.98,
#   'high': 23.95,
#   'low': 22.98,
#   'close': 23.79,
#   'volume': 60400366,
#   'change': 0.81,
#   'changePercent': 3.52,
#   'vwap': 23.425},
#  {'symbol': 'PLTR',
#   'date': '2024-06-05',
#   'open': 22.48,
#   'high': 22.98,
#   'low': 22.22,
#   'close': 22.96,
#   'volume': 39825392,
#   'change': 0.48,
#   'changePercent': 2.14,
#   'vwap': 22.66},
#  {'symbol': 'PLTR',
#   'date': '2024-06-04',
#   'open': 21.05,
#   'high': 22.26,
#   'low': 21.04,
#   'close': 22.1,
#   'volume': 41974047,
#   'change': 1.05,
#   'changePercent': 4.99,
#   'vwap': 21.6125},
#  {'symbol': 'PLTR',
#   'date': '2024-06-03',
#   'open': 21.7,
#   'high': 21.79,
#   'low': 21.01,
#   'close': 21.32,
#   'volume': 33876070,
#   'change': -0.38,
#   'changePercent': -1.75,
#   'vwap': 21.455},
#  {'symbol': 'PLTR',
#   'date': '2024-05-31',
#   'open': 21.79,
#   'high': 22.2,
#   'low': 21.31,
#   'close': 21.68,
#   'volume': 44416074,
#   'change': -0.11,
#   'changePercent': -0.50482,
#   'vwap': 21.745},
#  {'symbol': 'PLTR',
#   'date': '2024-05-30',
#   'open': 21.28,
#   'high': 21.96,
#   'low': 21.02,
#   'close': 21.73,
#   'volume': 47583129,
#   'change': 0.45,
#   'changePercent': 2.11,
#   'vwap': 21.4975},
#  {'symbol': 'PLTR',
#   'date': '2024-05-29',
#   'open': 20.77,
#   'high': 20.99,
#   'low': 20.64,
#   'close': 20.94,
#   'volume': 24834240,
#   'change': 0.17,
#   'changePercent': 0.81849,
#   'vwap': 20.835},
#  {'symbol': 'PLTR',
#   'date': '2024-05-28',
#   'open': 21.06,
#   'high': 21.22,
#   'low': 20.73,
#   'close': 21.05,
#   'volume': 26274188,
#   'change': -0.01,
#   'changePercent': -0.04748338,
#   'vwap': 21.015},
#  {'symbol': 'PLTR',
#   'date': '2024-05-24',
#   'open': 20.72,
#   'high': 21.15,
#   'low': 20.65,
#   'close': 21.01,
#   'volume': 22158712,
#   'change': 0.29,
#   'changePercent': 1.4,
#   'vwap': 20.8825},
#  {'symbol': 'PLTR',
#   'date': '2024-05-23',
#   'open': 21.39,
#   'high': 21.52,
#   'low': 20.63,
#   'close': 20.72,
#   'volume': 36887627,
#   'change': -0.67,
#   'changePercent': -3.13,
#   'vwap': 21.065},
#  {'symbol': 'PLTR',
#   'date': '2024-05-22',
#   'open': 21.23,
#   'high': 21.42,
#   'low': 21.08,
#   'close': 21.17,
#   'volume': 25212469,
#   'change': -0.06,
#   'changePercent': -0.28262,
#   'vwap': 21.225},
#  {'symbol': 'PLTR',
#   'date': '2024-05-21',
#   'open': 21.34,
#   'high': 21.45,
#   'low': 21.12,
#   'close': 21.24,
#   'volume': 27953962,
#   'change': -0.1,
#   'changePercent': -0.4686,
#   'vwap': 21.2875},
#  {'symbol': 'PLTR',
#   'date': '2024-05-20',
#   'open': 21.77,
#   'high': 21.77,
#   'low': 21.22,
#   'close': 21.62,
#   'volume': 35255258,
#   'change': -0.15,
#   'changePercent': -0.68902,
#   'vwap': 21.595},
#  {'symbol': 'PLTR',
#   'date': '2024-05-17',
#   'open': 21.78,
#   'high': 22.17,
#   'low': 21.56,
#   'close': 21.76,
#   'volume': 30032254,
#   'change': -0.02,
#   'changePercent': -0.09182736,
#   'vwap': 21.8175},
#  {'symbol': 'PLTR',
#   'date': '2024-05-16',
#   'open': 21.74,
#   'high': 21.87,
#   'low': 21.54,
#   'close': 21.65,
#   'volume': 27416677,
#   'change': -0.09,
#   'changePercent': -0.41398,
#   'vwap': 21.7},
#  {'symbol': 'PLTR',
#   'date': '2024-05-15',
#   'open': 21.73,
#   'high': 21.81,
#   'low': 21.19,
#   'close': 21.67,
#   'volume': 39424029,
#   'change': -0.06,
#   'changePercent': -0.27612,
#   'vwap': 21.6},
#  {'symbol': 'PLTR',
#   'date': '2024-05-14',
#   'open': 20.95,
#   'high': 22.07,
#   'low': 20.93,
#   'close': 21.44,
#   'volume': 57894354,
#   'change': 0.49,
#   'changePercent': 2.34,
#   'vwap': 21.3475},
#  {'symbol': 'PLTR',
#   'date': '2024-05-13',
#   'open': 20.6,
#   'high': 21.19,
#   'low': 20.6,
#   'close': 20.94,
#   'volume': 37524809,
#   'change': 0.34,
#   'changePercent': 1.65,
#   'vwap': 20.8325},
#  {'symbol': 'PLTR',
#   'date': '2024-05-10',
#   'open': 21.27,
#   'high': 21.37,
#   'low': 20.5,
#   'close': 20.6,
#   'volume': 59845413,
#   'change': -0.67,
#   'changePercent': -3.15,
#   'vwap': 20.935},
#  {'symbol': 'PLTR',
#   'date': '2024-05-09',
#   'open': 21.49,
#   'high': 21.58,
#   'low': 20.94,
#   'close': 21.14,
#   'volume': 54101937,
#   'change': -0.35,
#   'changePercent': -1.63,
#   'vwap': 21.2875},
#  {'symbol': 'PLTR',
#   'date': '2024-05-08',
#   'open': 21.58,
#   'high': 21.73,
#   'low': 21.06,
#   'close': 21.56,
#   'volume': 67582882,
#   'change': -0.02,
#   'changePercent': -0.09267841,
#   'vwap': 21.4825},
#  {'symbol': 'PLTR',
#   'date': '2024-05-07',
#   'open': 21.99,
#   'high': 22.7,
#   'low': 21.35,
#   'close': 21.4,
#   'volume': 161061622,
#   'change': -0.59,
#   'changePercent': -2.68,
#   'vwap': 21.86},
#  {'symbol': 'PLTR',
#   'date': '2024-05-06',
#   'open': 24.37,
#   'high': 25.36,
#   'low': 24.03,
#   'close': 25.21,
#   'volume': 175936565,
#   'change': 0.84,
#   'changePercent': 3.45,
#   'vwap': 24.7425},
#  {'symbol': 'PLTR',
#   'date': '2024-05-03',
#   'open': 23.48,
#   'high': 23.64,
#   'low': 22.91,
#   'close': 23.33,
#   'volume': 55976409,
#   'change': -0.15,
#   'changePercent': -0.63884,
#   'vwap': 23.34},
#  {'symbol': 'PLTR',
#   'date': '2024-05-02',
#   'open': 22.6,
#   'high': 22.72,
#   'low': 22.1,
#   'close': 22.55,
#   'volume': 30396133,
#   'change': -0.05,
#   'changePercent': -0.22124,
#   'vwap': 22.4925},
#  {'symbol': 'PLTR',
#   'date': '2024-05-01',
#   'open': 21.93,
#   'high': 22.83,
#   'low': 21.63,
#   'close': 22.12,
#   'volume': 34812852,
#   'change': 0.19,
#   'changePercent': 0.86639,
#   'vwap': 22.1275},
#  {'symbol': 'PLTR',
#   'date': '2024-04-30',
#   'open': 22.77,
#   'high': 22.87,
#   'low': 21.95,
#   'close': 21.97,
#   'volume': 30511879,
#   'change': -0.8,
#   'changePercent': -3.51,
#   'vwap': 22.39},
#  {'symbol': 'PLTR',
#   'date': '2024-04-29',
#   'open': 22.75,
#   'high': 23.09,
#   'low': 22.55,
#   'close': 22.83,
#   'volume': 30330698,
#   'change': 0.08,
#   'changePercent': 0.35165,
#   'vwap': 22.805},
#  {'symbol': 'PLTR',
#   'date': '2024-04-26',
#   'open': 22.05,
#   'high': 22.67,
#   'low': 21.91,
#   'close': 22.52,
#   'volume': 33119766,
#   'change': 0.47,
#   'changePercent': 2.13,
#   'vwap': 22.2875},
#  {'symbol': 'PLTR',
#   'date': '2024-04-25',
#   'open': 20.82,
#   'high': 21.74,
#   'low': 20.66,
#   'close': 21.71,
#   'volume': 26226705,
#   'change': 0.89,
#   'changePercent': 4.27,
#   'vwap': 21.2325},
#  {'symbol': 'PLTR',
#   'date': '2024-04-24',
#   'open': 22.05,
#   'high': 22.25,
#   'low': 21.3,
#   'close': 21.59,
#   'volume': 34426476,
#   'change': -0.46,
#   'changePercent': -2.09,
#   'vwap': 21.7975},
#  {'symbol': 'PLTR',
#   'date': '2024-04-23',
#   'open': 21.25,
#   'high': 22.06,
#   'low': 21.23,
#   'close': 21.64,
#   'volume': 36304634,
#   'change': 0.39,
#   'changePercent': 1.84,
#   'vwap': 21.545},
#  {'symbol': 'PLTR',
# ...
#   'close': 24.9,
#   'volume': 52395086,
#   'change': -0.1,
#   'changePercent': -0.4,
#   'vwap': 24.81},
#  {'symbol': 'PLTR',
#   'date': '2021-08-12',
#   'open': 24.45,
#   'high': 25.76,
#   'low': 23.585,
#   'close': 24.89,
#   'volume': 189542237,
#   'change': 0.44,
#   'changePercent': 1.8,
#   'vwap': 24.85},
#  {'symbol': 'PLTR',
#   'date': '2021-08-11',
#   'open': 23.07,
#   'high': 23.19,
#   'low': 22.09,
#   'close': 22.35,
#   'volume': 34532770,
#   'change': -0.72,
#   'changePercent': -3.12,
#   'vwap': 22.48},
#  {'symbol': 'PLTR',
#   'date': '2021-08-10',
#   'open': 23.01,
#   'high': 23.52,
#   'low': 22.78,
#   'close': 22.92,
#   'volume': 25947920,
#   'change': -0.09,
#   'changePercent': -0.39113,
#   'vwap': 23.05},
#  {'symbol': 'PLTR',
#   'date': '2021-08-09',
#   'open': 21.85,
#   'high': 23.28,
#   'low': 21.8,
#   'close': 22.93,
#   'volume': 35611060,
#   'change': 1.08,
#   'changePercent': 4.94,
#   'vwap': 22.83},
#  {'symbol': 'PLTR',
#   'date': '2021-08-06',
#   'open': 22.64,
#   'high': 22.69,
#   'low': 21.79,
#   'close': 21.82,
#   'volume': 24200671,
#   'change': -0.82,
#   'changePercent': -3.62,
#   'vwap': 22.02},
#  {'symbol': 'PLTR',
#   'date': '2021-08-05',
#   'open': 22.22,
#   'high': 22.77,
#   'low': 22.02,
#   'close': 22.52,
#   'volume': 18575248,
#   'change': 0.3,
#   'changePercent': 1.35,
#   'vwap': 22.51},
#  {'symbol': 'PLTR',
#   'date': '2021-08-04',
#   'open': 22.2,
#   'high': 22.54,
#   'low': 22.07,
#   'close': 22.3,
#   'volume': 15537433,
#   'change': 0.1,
#   'changePercent': 0.45045,
#   'vwap': 22.3},
#  {'symbol': 'PLTR',
#   'date': '2021-08-03',
#   'open': 22.03,
#   'high': 22.27,
#   'low': 21.71,
#   'close': 22.24,
#   'volume': 17040068,
#   'change': 0.21,
#   'changePercent': 0.95325,
#   'vwap': 21.98},
#  {'symbol': 'PLTR',
#   'date': '2021-08-02',
#   'open': 21.91,
#   'high': 22.37,
#   'low': 21.48,
#   'close': 22.1,
#   'volume': 21372877,
#   'change': 0.19,
#   'changePercent': 0.86718,
#   'vwap': 22.07},
#  {'symbol': 'PLTR',
#   'date': '2021-07-30',
#   'open': 21.85,
#   'high': 22.406,
#   'low': 21.71,
#   'close': 21.71,
#   'volume': 15889153,
#   'change': -0.14,
#   'changePercent': -0.64073,
#   'vwap': 21.97},
#  {'symbol': 'PLTR',
#   'date': '2021-07-29',
#   'open': 22.78,
#   'high': 22.85,
#   'low': 22.14,
#   'close': 22.18,
#   'volume': 19219083,
#   'change': -0.6,
#   'changePercent': -2.63,
#   'vwap': 22.42},
#  {'symbol': 'PLTR',
#   'date': '2021-07-28',
#   'open': 21.75,
#   'high': 22.615,
#   'low': 21.69,
#   'close': 22.56,
#   'volume': 25276982,
#   'change': 0.81,
#   'changePercent': 3.72,
#   'vwap': 22.38},
#  {'symbol': 'PLTR',
#   'date': '2021-07-27',
#   'open': 21.96,
#   'high': 22.11,
#   'low': 21.09,
#   'close': 21.68,
#   'volume': 23292433,
#   'change': -0.28,
#   'changePercent': -1.28,
#   'vwap': 21.47},
#  {'symbol': 'PLTR',
#   'date': '2021-07-26',
#   'open': 21.8,
#   'high': 22.3,
#   'low': 21.48,
#   'close': 22.13,
#   'volume': 16511113,
#   'change': 0.33,
#   'changePercent': 1.51,
#   'vwap': 21.98},
#  {'symbol': 'PLTR',
#   'date': '2021-07-23',
#   'open': 22.01,
#   'high': 22.08,
#   'low': 21.51,
#   'close': 21.81,
#   'volume': 17830854,
#   'change': -0.2,
#   'changePercent': -0.90868,
#   'vwap': 21.83},
#  {'symbol': 'PLTR',
#   'date': '2021-07-22',
#   'open': 22.55,
#   'high': 22.67,
#   'low': 21.88,
#   'close': 22.07,
#   'volume': 17763644,
#   'change': -0.48,
#   'changePercent': -2.13,
#   'vwap': 22.12},
#  {'symbol': 'PLTR',
#   'date': '2021-07-21',
#   'open': 22.27,
#   'high': 22.68,
#   'low': 22.12,
#   'close': 22.52,
#   'volume': 20737073,
#   'change': 0.25,
#   'changePercent': 1.12,
#   'vwap': 22.47},
#  {'symbol': 'PLTR',
#   'date': '2021-07-20',
#   'open': 21.63,
#   'high': 22.35,
#   'low': 21.22,
#   'close': 22.18,
#   'volume': 23287310,
#   'change': 0.55,
#   'changePercent': 2.54,
#   'vwap': 21.87},
#  {'symbol': 'PLTR',
#   'date': '2021-07-19',
#   'open': 20.97,
#   'high': 21.69,
#   'low': 20.55,
#   'close': 21.54,
#   'volume': 31019389,
#   'change': 0.57,
#   'changePercent': 2.72,
#   'vwap': 21.2},
#  {'symbol': 'PLTR',
#   'date': '2021-07-16',
#   'open': 21.6,
#   'high': 21.71,
#   'low': 21.24,
#   'close': 21.37,
#   'volume': 19745398,
#   'change': -0.23,
#   'changePercent': -1.06,
#   'vwap': 21.44},
#  {'symbol': 'PLTR',
#   'date': '2021-07-15',
#   'open': 21.72,
#   'high': 22.055,
#   'low': 21.01,
#   'close': 21.47,
#   'volume': 32342676,
#   'change': -0.25,
#   'changePercent': -1.15,
#   'vwap': 21.5},
#  {'symbol': 'PLTR',
#   'date': '2021-07-14',
#   'open': 22.49,
#   'high': 22.62,
#   'low': 21.51,
#   'close': 21.56,
#   'volume': 34072936,
#   'change': -0.93,
#   'changePercent': -4.14,
#   'vwap': 21.86},
#  {'symbol': 'PLTR',
#   'date': '2021-07-13',
#   'open': 22.98,
#   'high': 22.99,
#   'low': 22.42,
#   'close': 22.45,
#   'volume': 25016631,
#   'change': -0.53,
#   'changePercent': -2.31,
#   'vwap': 22.63},
#  {'symbol': 'PLTR',
#   'date': '2021-07-12',
#   'open': 23.26,
#   'high': 23.495,
#   'low': 22.88,
#   'close': 22.95,
#   'volume': 23922022,
#   'change': -0.31,
#   'changePercent': -1.33,
#   'vwap': 23.1},
#  {'symbol': 'PLTR',
#   'date': '2021-07-09',
#   'open': 22.96,
#   'high': 23.39,
#   'low': 22.76,
#   'close': 23.29,
#   'volume': 22926950,
#   'change': 0.33,
#   'changePercent': 1.44,
#   'vwap': 23.12},
#  {'symbol': 'PLTR',
#   'date': '2021-07-08',
#   'open': 22.43,
#   'high': 23.21,
#   'low': 22.25,
#   'close': 23.08,
#   'volume': 35421100,
#   'change': 0.65,
#   'changePercent': 2.9,
#   'vwap': 22.84},
#  {'symbol': 'PLTR',
#   'date': '2021-07-07',
#   'open': 24.23,
#   'high': 24.26,
#   'low': 22.72,
#   'close': 22.89,
#   'volume': 67420641,
#   'change': -1.34,
#   'changePercent': -5.53,
#   'vwap': 23.22},
#  {'symbol': 'PLTR',
#   'date': '2021-07-06',
#   'open': 24.6,
#   'high': 25.2,
#   'low': 24.47,
#   'close': 24.68,
#   'volume': 28894411,
#   'change': 0.08,
#   'changePercent': 0.3252,
#   'vwap': 24.76},
#  {'symbol': 'PLTR',
#   'date': '2021-07-02',
#   'open': 25,
#   'high': 25.34,
#   'low': 24.33,
#   'close': 24.44,
#   'volume': 29979403,
#   'change': -0.56,
#   'changePercent': -2.24,
#   'vwap': 24.68},
#  {'symbol': 'PLTR',
#   'date': '2021-07-01',
#   'open': 26.1,
#   'high': 26.13,
#   'low': 24.59,
#   'close': 24.72,
#   'volume': 55956752,
#   'change': -1.38,
#   'changePercent': -5.29,
#   'vwap': 25.1},
#  {'symbol': 'PLTR',
#   'date': '2021-06-30',
#   'open': 26.48,
#   'high': 26.92,
#   'low': 26.21,
#   'close': 26.36,
#   'volume': 29399829,
#   'change': -0.12,
#   'changePercent': -0.45317,
#   'vwap': 26.56},
#  {'symbol': 'PLTR',
#   'date': '2021-06-29',
#   'open': 27.38,
#   'high': 27.44,
#   'low': 26.44,
#   'close': 26.63,
#   'volume': 38858737,
#   'change': -0.75,
#   'changePercent': -2.74,
#   'vwap': 26.77},
#  {'symbol': 'PLTR',
#   'date': '2021-06-28',
#   'open': 26.98,
#   'high': 27.5,
#   'low': 26.86,
#   'close': 27.38,
#   'volume': 42645936,
#   'change': 0.4,
#   'changePercent': 1.48,
#   'vwap': 27.25},
#  {'symbol': 'PLTR',
#   'date': '2021-06-25',
#   'open': 26.58,
#   'high': 27.01,
#   'low': 26.245,
#   'close': 26.78,
#   'volume': 141168351,
#   'change': 0.2,
#   'changePercent': 0.75245,
#   'vwap': 26.76},
#  {'symbol': 'PLTR',
#   'date': '2021-06-24',
#   'open': 26.49,
#   'high': 26.71,
#   'low': 26.17,
#   'close': 26.53,
#   'volume': 49042923,
#   'change': 0.04,
#   'changePercent': 0.151,
#   'vwap': 26.5},
#  {'symbol': 'PLTR',
#   'date': '2021-06-23',
#   'open': 25.46,
#   'high': 26.35,
#   'low': 25.34,
#   'close': 26.27,
#   'volume': 53700013,
#   'change': 0.81,
#   'changePercent': 3.18,
#   'vwap': 26.04},
#  {'symbol': 'PLTR',
#   'date': '2021-06-22',
#   'open': 25.39,
#   'high': 25.52,
#   'low': 24.96,
#   'close': 25.4,
#   'volume': 46553117,
#   'change': 0.01,
#   'changePercent': 0.03938558,
#   'vwap': 25.28},
#  {'symbol': 'PLTR',
#   'date': '2021-06-21',
#   'open': 25.1,
#   'high': 25.55,
#   'low': 24.51,
#   'close': 25.42,
#   'volume': 55336374,
#   'change': 0.32,
#   'changePercent': 1.27,
#   'vwap': 25.25},
#  {'symbol': 'PLTR',
#   'date': '2021-06-18',
#   'open': 25.59,
#   'high': 25.94,
#   'low': 25.02,
#   'close': 25.37,
#   'volume': 66482972,
#   'change': -0.22,
#   'changePercent': -0.85971,
#   'vwap': 25.36},
#  {'symbol': 'PLTR',
#   'date': '2021-06-17',
#   'open': 24.68,
#   'high': 25.46,
#   'low': 24.55,
#   'close': 25.45,
#   'volume': 64694885,
#   'change': 0.77,
#   'changePercent': 3.12,
#   'vwap': 25.22},
#  {'symbol': 'PLTR',
#   'date': '2021-06-16',
#   'open': 24.09,
#   'high': 24.94,
#   'low': 23.86,
#   'close': 24.8,
#   'volume': 57382668,
#   'change': 0.71,
#   'changePercent': 2.95,
#   'vwap': 24.61},
#  {'symbol': 'PLTR',
#   'date': '2021-06-15',
#   'open': 25.03,
#   'high': 25.55,
#   'low': 24.39,
#   'close': 24.41,
#   'volume': 47062777,
#   'change': -0.62,
#   'changePercent': -2.48,
#   'vwap': 24.88},
#  {'symbol': 'PLTR',
#   'date': '2021-06-14',
#   'open': 24.73,
#   'high': 25.15,
#   'low': 24.47,
#   'close': 25,
#   'volume': 52163099,
#   'change': 0.27,
#   'changePercent': 1.09,
#   'vwap': 24.9},
#  {'symbol': 'PLTR',
#   'date': '2021-06-11',
#   'open': 24.12,
#   'high': 24.71,
#   'low': 24.03,
#   'close': 24.67,
#   'volume': 33403258,
#   'change': 0.55,
#   'changePercent': 2.28,
#   'vwap': 24.48},
#  {'symbol': 'PLTR',
#   'date': '2021-06-10',
#   'open': 24,
#   'high': 24.39,
#   'low': 23.44,
#   'close': 24.14,
#   'volume': 35901102,
#   'change': 0.14,
#   'changePercent': 0.58333,
#   'vwap': 24.02},
#  {'symbol': 'PLTR',
#   'date': '2021-06-09',
#   'open': 24.45,
#   'high': 24.74,
#   'low': 24.17,
#   'close': 24.17,
#   'volume': 36349053,
#   'change': -0.28,
#   'changePercent': -1.15,
#   'vwap': 24.46},
#  {'symbol': 'PLTR',
#   'date': '2021-06-08',
#   'open': 24.85,
#   'high': 25.23,
#   'low': 23.93,
#   'close': 24.38,
#   'volume': 54068228,
#   'change': -0.47,
#   'changePercent': -1.89,
#   'vwap': 24.51},
#  {'symbol': 'PLTR',
#   'date': '2021-06-07',
#   'open': 24,
#   'high': 24.76,
#   'low': 23.79,
#   'close': 24.46,
#   'volume': 50042601,
#   'change': 0.46,
#   'changePercent': 1.92,
#   'vwap': 24.4},
#  {'symbol': 'PLTR',
#   'date': '2021-06-04',
#   'open': 23.71,
#   'high': 24.49,
#   'low': 23.5,
#   'close': 24.03,
#   'volume': 42865515,
#   'change': 0.32,
#   'changePercent': 1.35,
#   'vwap': 24.08},
#  {'symbol': 'PLTR',
#   'date': '2021-06-03',
#   'open': 24.14,
#   'high': 24.26,
#   'low': 23.34,
#   'close': 23.63,
#   'volume': 48762057,
#   'change': -0.51,
#   'changePercent': -2.11,
#   'vwap': 23.85},
#  {'symbol': 'PLTR',
#   'date': '2021-06-02',
#   'open': 23.02,
#   'high': 24.84,
#   'low': 22.82,
#   'close': 24.45,
#   'volume': 86996445,
#   'change': 1.43,
#   'changePercent': 6.21,
#   'vwap': 24.02},
#  {'symbol': 'PLTR',
#   'date': '2021-06-01',
#   'open': 23.19,
#   'high': 23.3499,
#   'low': 22.36,
#   'close': 23.06,
#   'volume': 53465569,
#   'change': -0.13,
#   'changePercent': -0.56059,
#   'vwap': 22.95},
#  {'symbol': 'PLTR',
#   'date': '2021-05-28',
#   'open': 23,
#   'high': 24.75,
#   'low': 22.76,
#   'close': 22.95,
#   'volume': 112775179,
#   'change': -0.05,
#   'changePercent': -0.21739,
#   'vwap': 23.64},
#  {'symbol': 'PLTR',
#   'date': '2021-05-27',
#   'open': 22.01,
#   'high': 22.7,
#   'low': 21.65,
#   'close': 22.7,
#   'volume': 76855155,
#   'change': 0.69,
#   'changePercent': 3.13,
#   'vwap': 22.4},
#  {'symbol': 'PLTR',
#   'date': '2021-05-26',
#   'open': 21.58,
#   'high': 22.24,
#   'low': 21.49,
#   'close': 22.12,
#   'volume': 43400731,
#   'change': 0.54,
#   'changePercent': 2.5,
#   'vwap': 22.02},
#  {'symbol': 'PLTR',
#   'date': '2021-05-25',
#   'open': 21.42,
#   'high': 22.11,
#   'low': 21.28,
#   'close': 21.48,
#   'volume': 50375953,
#   'change': 0.06,
#   'changePercent': 0.28011,
#   'vwap': 21.68},
#  {'symbol': 'PLTR',
#   'date': '2021-05-24',
#   'open': 21.06,
#   'high': 21.52,
#   'low': 20.675,
#   'close': 21.22,
#   'volume': 46974997,
#   'change': 0.16,
#   'changePercent': 0.75973,
#   'vwap': 21.1},
#  {'symbol': 'PLTR',
#   'date': '2021-05-21',
#   'open': 20.84,
#   'high': 21.16,
#   'low': 20.47,
#   'close': 20.75,
#   'volume': 35811544,
#   'change': -0.09,
#   'changePercent': -0.43186,
#   'vwap': 20.86},
#  {'symbol': 'PLTR',
#   'date': '2021-05-20',
#   'open': 20.75,
#   'high': 20.81,
#   'low': 20.28,
#   'close': 20.61,
#   'volume': 46701279,
#   'change': -0.14,
#   'changePercent': -0.6747,
#   'vwap': 20.52},
#  {'symbol': 'PLTR',
#   'date': '2021-05-19',
#   'open': 20.1,
#   'high': 21.035,
#   'low': 19.94,
#   'close': 20.67,
#   'volume': 46058717,
#   'change': 0.57,
#   'changePercent': 2.84,
#   'vwap': 20.63},
#  {'symbol': 'PLTR',
#   'date': '2021-05-18',
#   'open': 20.52,
#   'high': 21.62,
#   'low': 20.26,
#   'close': 21.24,
#   'volume': 59955562,
#   'change': 0.72,
#   'changePercent': 3.51,
#   'vwap': 21.16},
#  {'symbol': 'PLTR',
#   'date': '2021-05-17',
#   'open': 19.73,
#   'high': 20.49,
#   'low': 19.63,
#   'close': 20.46,
#   'volume': 50531808,
#   'change': 0.73,
#   'changePercent': 3.7,
#   'vwap': 20.18},
#  {'symbol': 'PLTR',
#   'date': '2021-05-14',
#   'open': 18.82,
#   'high': 20.2,
#   'low': 18.53,
#   'close': 20.08,
#   'volume': 79975558,
#   'change': 1.26,
#   'changePercent': 6.7,
#   'vwap': 19.64},
#  {'symbol': 'PLTR',
#   'date': '2021-05-13',
#   'open': 19.14,
#   'high': 19.47,
#   'low': 17.82,
#   'close': 18.37,
#   'volume': 88647412,
#   'change': -0.77,
#   'changePercent': -4.02,
#   'vwap': 18.64},
#  {'symbol': 'PLTR',
#   'date': '2021-05-12',
#   'open': 20,
#   'high': 20,
#   'low': 18.51,
#   'close': 18.89,
#   'volume': 129539228,
#   'change': -1.11,
#   'changePercent': -5.55,
#   'vwap': 19.06},
#  {'symbol': 'PLTR',
#   'date': '2021-05-11',
#   'open': 17.2,
#   'high': 20.3,
#   'low': 17.055,
#   'close': 20.21,
#   'volume': 205157902,
#   'change': 3.01,
#   'changePercent': 17.5,
#   'vwap': 19.27},
#  {'symbol': 'PLTR',
#   'date': '2021-05-10',
#   'open': 19.28,
#   'high': 19.3,
#   'low': 18.18,
#   'close': 18.47,
#   'volume': 105708253,
#   'change': -0.81,
#   'changePercent': -4.2,
#   'vwap': 18.64},
#  {'symbol': 'PLTR',
#   'date': '2021-05-07',
#   'open': 20.3,
#   'high': 20.75,
#   'low': 19.58,
#   'close': 19.75,
#   'volume': 64288761,
#   'change': -0.55,
#   'changePercent': -2.71,
#   'vwap': 20.1},
#  {'symbol': 'PLTR',
#   'date': '2021-05-06',
#   'open': 21.02,
#   'high': 21.02,
#   'low': 19.41,
#   'close': 20.09,
#   'volume': 92618718,
#   'change': -0.93,
#   'changePercent': -4.42,
#   'vwap': 20.07},
#  {'symbol': 'PLTR',
#   'date': '2021-05-05',
#   'open': 21.81,
#   'high': 21.94,
#   'low': 20.97,
#   'close': 21.15,
#   'volume': 39535986,
#   'change': -0.66,
#   'changePercent': -3.03,
#   'vwap': 21.44},
#  {'symbol': 'PLTR',
#   'date': '2021-05-04',
#   'open': 21.94,
#   'high': 22.2,
#   'low': 20.87,
#   'close': 21.64,
#   'volume': 63968479,
#   'change': -0.3,
#   'changePercent': -1.37,
#   'vwap': 21.32},
#  {'symbol': 'PLTR',
#   'date': '2021-05-03',
#   'open': 23.01,
#   'high': 23.08,
#   'low': 22.21,
#   'close': 22.3,
#   'volume': 34268890,
#   'change': -0.71,
#   'changePercent': -3.09,
#   'vwap': 22.48},
#  {'symbol': 'PLTR',
#   'date': '2021-04-30',
#   'open': 23.18,
#   'high': 23.55,
#   'low': 22.84,
#   'close': 23.04,
#   'volume': 25143934,
#   'change': -0.14,
#   'changePercent': -0.60397,
#   'vwap': 23.12},
#  {'symbol': 'PLTR',
#   'date': '2021-04-29',
#   'open': 23.87,
#   'high': 24.14,
#   'low': 22.81,
#   'close': 23.37,
#   'volume': 37007072,
#   'change': -0.5,
#   'changePercent': -2.09,
#   'vwap': 23.3},
#  {'symbol': 'PLTR',
#   'date': '2021-04-28',
#   'open': 23.67,
#   'high': 24.17,
#   'low': 23.42,
#   'close': 23.85,
#   'volume': 22367601,
#   'change': 0.18,
#   'changePercent': 0.76046,
#   'vwap': 23.84},
#  {'symbol': 'PLTR',
#   'date': '2021-04-27',
#   'open': 24.17,
#   'high': 24.26,
#   'low': 23.57,
#   'close': 23.88,
#   'volume': 27970217,
#   'change': -0.29,
#   'changePercent': -1.2,
#   'vwap': 23.95},
#  {'symbol': 'PLTR',
#   'date': '2021-04-26',
#   'open': 23.69,
#   'high': 24.26,
#   'low': 23.46,
#   'close': 24.11,
#   'volume': 34085325,
#   'change': 0.42,
#   'changePercent': 1.77,
#   'vwap': 23.91},
#  {'symbol': 'PLTR',
#   'date': '2021-04-23',
#   'open': 22.89,
#   'high': 23.55,
#   'low': 22.74,
#   'close': 23.41,
#   'volume': 32452811,
#   'change': 0.52,
#   'changePercent': 2.27,
#   'vwap': 23.34},
#  {'symbol': 'PLTR',
#   'date': '2021-04-22',
#   'open': 22.94,
#   'high': 23.51,
#   'low': 22.51,
#   'close': 22.86,
#   'volume': 51883467,
#   'change': -0.08,
#   'changePercent': -0.34874,
#   'vwap': 23.05},
#  {'symbol': 'PLTR',
#   'date': '2021-04-21',
#   'open': 21.65,
#   'high': 22.64,
#   'low': 21.43,
#   'close': 22.63,
#   'volume': 42784337,
#   'change': 0.98,
#   'changePercent': 4.53,
#   'vwap': 22.3},
#  {'symbol': 'PLTR',
#   'date': '2021-04-20',
#   'open': 21.96,
#   'high': 22.55,
#   'low': 21.24,
#   'close': 21.78,
#   'volume': 47509531,
#   'change': -0.18,
#   'changePercent': -0.81967,
#   'vwap': 21.73},
#  ...]

# %%
upload_data_to_s3(response)
# Out:
# Data uploaded successfully to S3
